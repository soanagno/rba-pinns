# %%
import os
import sys
import time
import torch
import random
import scipy.io
import numpy as np
from pyDOE import lhs
import matplotlib as mpl
import matplotlib.pyplot as plt
from torch.optim import lr_scheduler
from collections import OrderedDict

mpl.rcParams.update(mpl.rcParamsDefault)
np.set_printoptions(threshold=sys.maxsize)
plt.rcParams['figure.max_open_warning'] = 4

# %% [markdown]
# ## Global functions

# %%
if torch.cuda.is_available():
    """ Cuda support """
    print('cuda available')
    device = torch.device('cuda')
else:
    print('cuda not avail')
    device = torch.device('cpu')

def seed_torch(seed):
    """ Seed initialization """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
seed_torch(2341)
torch.cuda.empty_cache()

def tonp(tensor):
    """ Torch to Numpy """
    if isinstance(tensor, torch.Tensor):
        return tensor.detach().cpu().numpy()
    elif isinstance(tensor, np.ndarray):
        return tensor
    else:
        raise TypeError('Unknown type of input, expected torch.Tensor or '\
            'np.ndarray, but got {}'.format(type(input)))

def grad(u, x):
    """ Get grad """
    gradient = torch.autograd.grad(
        u, x,
        grad_outputs=torch.ones_like(u),
        retain_graph=True,
        create_graph=True
    )[0]
    return gradient
# Out:
# cuda available

# %% [markdown]
# ## Initializations

# %%
# File initializations
file_path = './'
file_name = 'losses.txt'

# Exact solution boundaries
data = scipy.io.loadmat(file_path + 'AC.mat')
Exact = data['uu']
Exact0 = np.real(Exact)
t0 = data['tt'].flatten()[:,None]
x0 = data['x'].flatten()[:,None]
lbc = torch.tensor([x0.min(), t0.min()]).to(torch.float32).to(device)
ubc = torch.tensor([x0.max(), t0.max()]).to(torch.float32).to(device)
nx, nt = 256*2, 201

# %% [markdown]
# ## DNN

# %%
class DNN(torch.nn.Module):
    """ DNN Class """
    
    def __init__(self, layers):
        super(DNN, self).__init__()
        self.depth = len(layers) - 1
        self.activation = torch.nn.Tanh
        
        # Layers
        layer_list = list()
        for i in range(self.depth - 1):
            w_layer = torch.nn.Linear(layers[i], layers[i+1], bias=True)
            torch.nn.init.xavier_normal_(w_layer.weight)
            layer_list.append(('layer_%d' % i, w_layer))
            layer_list.append(('activation_%d' % i, self.activation()))

        w_layer = torch.nn.Linear(layers[-2], layers[-1], bias=True)
        torch.nn.init.xavier_normal_(w_layer.weight)
        layer_list.append(('layer_%d' % (self.depth - 1), w_layer))
        layerDict = OrderedDict(layer_list)
        # Deploy layers
        self.layers = torch.nn.Sequential(layerDict)
        
    def forward(self, x):
        out = self.layers(x)
        return out

# %% [markdown]
# ## PINN

# %%
class PINN():
    """ PINN Class """
    
    def __init__(self, X_u, u, X_r, lb, ub, dimx, dimt, savept=None):
        
        # Initialization
        self.rba = 1  # RBA weights
        self.sa = 0   # SA weights
        self.neum = 0 # Symmetry bc
        self.iter = 0
        self.exec_time = 0
        self.print_step = 100
        self.savept = savept
        self.dimx, self.dimt = dimx, dimt
        self.dimx_, self.dimt_ = nx, nt  # solution dim
        self.first_opt = 30000
        self.it, self.l2, self.linf = [], [], []
        self.loss, self.losses = None, []

        # Intermediate results
        self.Exact = Exact0
        X, T = np.meshgrid(x0, t0)
        X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))
        self.xx = torch.tensor(X_star[:, 0:1]).float().to(device)
        self.tt = torch.tensor(X_star[:, 1:2]).float().to(device)
        
        # Data
        self.x_u = torch.tensor(X_u[:, 0:1], requires_grad=True).float().to(device)
        self.t_u = torch.tensor(X_u[:, 1:2], requires_grad=True).float().to(device)
        self.x_r = torch.tensor(X_r[:, 0:1], requires_grad=True).float().to(device)
        self.t_r = torch.tensor(X_r[:, 1:2], requires_grad=True).float().to(device)
        self.u = torch.tensor(u).float().to(device)
        self.N_r = tonp(self.x_r).size
        self.N_u = dimt
        self.dnn = DNN(layers).to(device)
        
        # RBA initialization
        if self.rba == 1:
            self.rsum = 0
            self.eta = 0.001
            self.gamma = 0.999
            self.init = 1  # initialization mode (1 or 2)
            
        # SA weights initialization
        if self.sa == 1:
            self.lamr = torch.rand(self.N_r, 1, requires_grad=True).float().to(device)*1
            self.lamu = torch.rand(self.N_u, 1, requires_grad=True).float().to(device)*100
            self.lamr = torch.nn.Parameter(self.lamr)
            self.lamu = torch.nn.Parameter(self.lamu)
            # Optimizer2 (SA weights)
            self.optimizer2 = torch.optim.Adam([self.lamr] + [self.lamu], lr=0.005, maximize=True)
            
        # Optimizer (1st ord)
        self.optimizer = torch.optim.Adam(self.dnn.parameters(), lr=1e-3, betas=(0.9, 0.999))
        self.scheduler = lr_scheduler.ExponentialLR(self.optimizer, gamma=0.9, verbose=True)
        self.step_size = 5000

    def net_u(self, x, t):
        """ Get the velocities """
        
        u = self.dnn(torch.cat([x, t], dim=1))
        return u

    def net_r(self, x, t):
        """ Residual calculation """
        
        u = self.net_u(x, t)
        u_t = grad(u, t)
        u_x = grad(u, x)
        u_xx = grad(u_x, x)
        f = u_t - 0.0001*u_xx + 5.0*u*u*u - 5.0*u
        return f, u_x

    def loss_func(self):
        """ Loss function """
        
        self.optimizer.zero_grad()
        if self.sa == 1:
            self.optimizer2.zero_grad()

        # Predictions
        self.u_pred = self.net_u(self.x_u, self.t_u)
        self.r_pred, u_x_pred = self.net_r(self.x_r, self.t_r)
        self.r_pred2, u_x_pred = self.net_r(self.x_u, self.t_u)

        if self.rba == True:
            eta = 1 if self.init == 2 and self.iter == 0 else self.eta
            r_norm = eta*torch.abs(self.r_pred)/torch.max(torch.abs(self.r_pred))
            self.rsum = (self.rsum*self.gamma + r_norm).detach()
            loss_r = torch.mean((self.rsum*self.r_pred)**2)
            loss_u = torch.mean((self.u_pred[:self.dimx] - self.u) ** 2)
            
        elif self.sa == True:
            loss_r = torch.mean((self.lamr*self.r_pred)**2)
            loss_u = torch.mean((self.lamu*(self.u_pred[:self.dimx] - self.u))**2)

        else:
            loss_r = torch.mean(self.r_pred**2)
            loss_u = torch.mean((self.u_pred[:self.dimx] - self.u)**2)
        
        # Symmetry bc
        if self.neum == 1:
            loss_ub = torch.mean((self.u_pred[self.dimx:self.dimx+self.N_u] - self.u_pred[-self.N_u:])**2)
        else:
            loss_ub = 0

        # Loss calculation
        self.loss = loss_r + loss_u + loss_ub
        self.loss.backward()
        self.iter += 1

        if self.iter % self.print_step == 0:
            
            with torch.no_grad():
                # Grid prediction (for relative L2)
                res = self.net_u(self.xx, self.tt)
                sol = tonp(res)
                sol = np.reshape(sol, (self.dimt_, self.dimx_)).T

                # L2 calculation
                l2_rel = np.linalg.norm(self.Exact.flatten() - sol.flatten(), 2) / np.linalg.norm(self.Exact.flatten(), 2)
                l_inf = np.linalg.norm(self.Exact.flatten() - sol.flatten(), np.inf) / np.linalg.norm(self.Exact.flatten(), np.inf)
                print('Iter %d, Loss: %.3e, Rel_L2: %.3e, L_inf: %.3e, t/iter: %.1e' % 
                     (self.iter, self.loss.item(), l2_rel, l_inf, self.exec_time))
                print()
                
                self.it.append(self.iter)
                self.l2.append(l2_rel)
                self.linf.append(l_inf)

        # Optimizer step
        self.optimizer.step()
        self.losses.append(self.loss.item())
        if self.sa == True:
            self.optimizer2.step()
                
    def train(self):
        """ Train model """
        
        self.dnn.train()
        for epoch in range(self.first_opt):
            start_time = time.time()
            self.loss_func()
            end_time = time.time()
            self.exec_time = end_time - start_time
            if (epoch+1) % self.step_size == 0:
                self.scheduler.step()

        # Write data
        a = np.array(self.it)
        b = np.array(self.l2)
        c = np.array(self.linf)
        # Stack them into a 2D array.
        d = np.column_stack((a, b, c))
        file = open(file_path + file_name, "w+")
        file.close()
        file = open(file_path + file_name, "w+")
        file.close()
        # Write to a txt file
        np.savetxt('losses.txt', d, fmt='%.10f %.10f %.10f')

        if self.savept != None:
            torch.save(self.dnn.state_dict(), str(self.savept)+".pt")
    
    def predict(self, X):
        x = torch.tensor(X[:, 0:1]).float().to(device)
        t = torch.tensor(X[:, 1:2]).float().to(device)
        self.dnn.eval()
        u = self.net_u(x, t)
        u = tonp(u)
        return u

# %% [markdown]
# ## Data generation

# %%
# Collocation points
dimx = 256*2
dimt = 201
N_u = 100
N_r = 25600
hidden = 128
layers = [2] + [hidden]*6 + [1]

# Definition
Exact = Exact0.T
tm = np.linspace(t0.min(), t0.max(), dimt)[:, None]
xm = np.linspace(x0.min(), x0.max(), dimx)[:, None]
X, T = np.meshgrid(xm, tm)
X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))
xx1 = np.hstack((X[0:1,:].T, T[0:1,:].T))
uu1 = Exact[0:1,:].T
u_train = uu1

# Doman bounds
lb = X_star.min(0)
ub = X_star.max(0)

plt.figure(1)
plt.title('Initial condition')
plt.plot(np.arange(uu1.shape[0]), uu1)
plt.show()

# Top/bot boundaries
xx2 = np.hstack((X[:,0:1], T[:,0:1]))
xx3 = np.hstack((X[:,-1:], T[:,-1:]))

# Random selection
idx = np.random.choice(dimt, N_u, replace=False)
idx2 = np.random.choice(dimt, N_u, replace=False)
X_u_train = np.vstack([xx1, xx2[idx, :], xx3[idx2, :]])

# Collocation points
X_r_train = lb + (ub-lb)*lhs(2, N_r)

print('X_r shape:', X_r_train.shape)
print('X_u shape:', X_u_train.shape)
print('u shape:', u_train.shape)
            
plt.figure(2)
plt.title('Collocation points')
plt.scatter(X_r_train[:, 1], X_r_train[:, 0], s=0.5)
plt.scatter(X_u_train[:, 1], X_u_train[:, 0], s=0.5, c='k')
plt.show()
# Out:
# X_r shape: (25600, 2)
# X_u shape: (712, 2)
# u shape: (512, 1)

# %%
model = PINN(X_u_train, u_train, X_r_train, lb, ub, dimx, dimt=N_u, savept='weights')
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.

# %% [markdown]
# ## Training

# %%
# %%time
model.train()  # RBA
# Out:
# Iter 100, Loss: 1.774e-02, Rel_L2: 7.557e-01, L_inf: 7.557e-01, t/iter: 1.7e-02
#
# Iter 200, Loss: 1.181e-02, Rel_L2: 7.656e-01, L_inf: 7.656e-01, t/iter: 1.7e-02
#
# Iter 300, Loss: 1.589e-03, Rel_L2: 7.359e-01, L_inf: 7.359e-01, t/iter: 1.7e-02
#
# Iter 400, Loss: 1.123e-03, Rel_L2: 7.738e-01, L_inf: 7.738e-01, t/iter: 1.7e-02
#
# Iter 500, Loss: 7.455e-04, Rel_L2: 8.154e-01, L_inf: 8.154e-01, t/iter: 1.7e-02
#
# Iter 600, Loss: 5.681e-04, Rel_L2: 8.293e-01, L_inf: 8.293e-01, t/iter: 1.7e-02
#
# Iter 700, Loss: 6.341e-04, Rel_L2: 8.171e-01, L_inf: 8.171e-01, t/iter: 1.7e-02
#
# Iter 800, Loss: 7.115e-04, Rel_L2: 8.061e-01, L_inf: 8.061e-01, t/iter: 1.7e-02
#
# Iter 900, Loss: 2.094e-01, Rel_L2: 9.960e-01, L_inf: 9.960e-01, t/iter: 1.7e-02
#
# Iter 1000, Loss: 9.831e-04, Rel_L2: 7.650e-01, L_inf: 7.650e-01, t/iter: 1.7e-02
#
# Iter 1100, Loss: 9.030e-04, Rel_L2: 7.839e-01, L_inf: 7.839e-01, t/iter: 1.7e-02
#
# Iter 1200, Loss: 9.255e-04, Rel_L2: 7.808e-01, L_inf: 7.808e-01, t/iter: 1.7e-02
#
# Iter 1300, Loss: 9.434e-04, Rel_L2: 7.760e-01, L_inf: 7.760e-01, t/iter: 1.7e-02
#
# Iter 1400, Loss: 9.568e-04, Rel_L2: 7.715e-01, L_inf: 7.715e-01, t/iter: 1.7e-02
#
# Iter 1500, Loss: 9.706e-04, Rel_L2: 7.665e-01, L_inf: 7.665e-01, t/iter: 1.7e-02
#
# Iter 1600, Loss: 9.659e-04, Rel_L2: 7.621e-01, L_inf: 7.621e-01, t/iter: 1.7e-02
#
# Iter 1700, Loss: 9.737e-04, Rel_L2: 7.573e-01, L_inf: 7.573e-01, t/iter: 1.7e-02
#
# Iter 1800, Loss: 9.875e-04, Rel_L2: 7.508e-01, L_inf: 7.508e-01, t/iter: 1.7e-02
#
# Iter 1900, Loss: 9.755e-04, Rel_L2: 7.468e-01, L_inf: 7.468e-01, t/iter: 1.7e-02
#
# Iter 2000, Loss: 9.770e-04, Rel_L2: 7.414e-01, L_inf: 7.414e-01, t/iter: 1.7e-02
#
# Iter 2100, Loss: 9.762e-04, Rel_L2: 7.356e-01, L_inf: 7.356e-01, t/iter: 1.7e-02
#
# Iter 2200, Loss: 9.728e-04, Rel_L2: 7.297e-01, L_inf: 7.297e-01, t/iter: 1.7e-02
#
# Iter 2300, Loss: 9.781e-04, Rel_L2: 7.256e-01, L_inf: 7.256e-01, t/iter: 1.7e-02
#
# Iter 2400, Loss: 9.581e-04, Rel_L2: 7.171e-01, L_inf: 7.171e-01, t/iter: 1.7e-02
#
# Iter 2500, Loss: 9.497e-04, Rel_L2: 7.104e-01, L_inf: 7.104e-01, t/iter: 1.7e-02
#
# Iter 2600, Loss: 2.903e-03, Rel_L2: 7.240e-01, L_inf: 7.240e-01, t/iter: 1.7e-02
#
# Iter 2700, Loss: 9.259e-04, Rel_L2: 6.960e-01, L_inf: 6.960e-01, t/iter: 1.7e-02
#
# Iter 2800, Loss: 9.090e-04, Rel_L2: 6.881e-01, L_inf: 6.881e-01, t/iter: 1.7e-02
#
# Iter 2900, Loss: 8.892e-04, Rel_L2: 6.799e-01, L_inf: 6.799e-01, t/iter: 1.7e-02
#
# Iter 3000, Loss: 8.676e-04, Rel_L2: 6.715e-01, L_inf: 6.715e-01, t/iter: 1.7e-02
#
# Iter 3100, Loss: 8.734e-04, Rel_L2: 6.615e-01, L_inf: 6.615e-01, t/iter: 1.7e-02
#
# Iter 3200, Loss: 8.287e-04, Rel_L2: 6.554e-01, L_inf: 6.554e-01, t/iter: 1.7e-02
#
# Iter 3300, Loss: 1.179e-03, Rel_L2: 6.437e-01, L_inf: 6.437e-01, t/iter: 1.7e-02
#
# Iter 3400, Loss: 8.828e-04, Rel_L2: 6.344e-01, L_inf: 6.344e-01, t/iter: 1.7e-02
#
# Iter 3500, Loss: 3.349e-03, Rel_L2: 6.170e-01, L_inf: 6.170e-01, t/iter: 1.7e-02
#
# Iter 3600, Loss: 1.981e-03, Rel_L2: 6.247e-01, L_inf: 6.247e-01, t/iter: 1.7e-02
#
# Iter 3700, Loss: 7.333e-04, Rel_L2: 6.213e-01, L_inf: 6.213e-01, t/iter: 1.7e-02
#
# Iter 3800, Loss: 7.213e-04, Rel_L2: 6.174e-01, L_inf: 6.174e-01, t/iter: 1.7e-02
#
# Iter 3900, Loss: 2.135e-03, Rel_L2: 6.230e-01, L_inf: 6.230e-01, t/iter: 1.7e-02
#
# Iter 4000, Loss: 1.464e-03, Rel_L2: 6.099e-01, L_inf: 6.099e-01, t/iter: 1.7e-02
#
# Iter 4100, Loss: 9.334e-04, Rel_L2: 6.011e-01, L_inf: 6.011e-01, t/iter: 1.7e-02
#
# Iter 4200, Loss: 6.630e-04, Rel_L2: 5.975e-01, L_inf: 5.975e-01, t/iter: 1.7e-02
#
# Iter 4300, Loss: 6.576e-04, Rel_L2: 5.929e-01, L_inf: 5.929e-01, t/iter: 1.7e-02
#
# Iter 4400, Loss: 6.528e-04, Rel_L2: 5.888e-01, L_inf: 5.888e-01, t/iter: 1.7e-02
#
# Iter 4500, Loss: 6.507e-04, Rel_L2: 5.842e-01, L_inf: 5.842e-01, t/iter: 1.7e-02
#
# Iter 4600, Loss: 6.387e-04, Rel_L2: 5.809e-01, L_inf: 5.809e-01, t/iter: 1.7e-02
#
# Iter 4700, Loss: 6.331e-04, Rel_L2: 5.772e-01, L_inf: 5.772e-01, t/iter: 1.7e-02
#
# Iter 4800, Loss: 6.227e-04, Rel_L2: 5.736e-01, L_inf: 5.736e-01, t/iter: 1.7e-02
#
# Iter 4900, Loss: 6.136e-04, Rel_L2: 5.699e-01, L_inf: 5.699e-01, t/iter: 1.7e-02
#
# Iter 5000, Loss: 6.081e-04, Rel_L2: 5.672e-01, L_inf: 5.672e-01, t/iter: 1.7e-02
#
# Adjusting learning rate of group 0 to 9.0000e-04.
# Iter 5100, Loss: 5.922e-04, Rel_L2: 5.630e-01, L_inf: 5.630e-01, t/iter: 1.7e-02
#
# Iter 5200, Loss: 5.830e-04, Rel_L2: 5.600e-01, L_inf: 5.600e-01, t/iter: 1.7e-02
#
# Iter 5300, Loss: 5.747e-04, Rel_L2: 5.573e-01, L_inf: 5.573e-01, t/iter: 1.7e-02
#
# Iter 5400, Loss: 6.808e-04, Rel_L2: 5.477e-01, L_inf: 5.477e-01, t/iter: 1.7e-02
#
# Iter 5500, Loss: 5.627e-04, Rel_L2: 5.538e-01, L_inf: 5.538e-01, t/iter: 1.7e-02
#
# Iter 5600, Loss: 5.589e-04, Rel_L2: 5.525e-01, L_inf: 5.525e-01, t/iter: 1.7e-02
#
# Iter 5700, Loss: 7.820e-04, Rel_L2: 5.596e-01, L_inf: 5.596e-01, t/iter: 1.7e-02
#
# Iter 5800, Loss: 5.544e-04, Rel_L2: 5.493e-01, L_inf: 5.493e-01, t/iter: 1.7e-02
#
# Iter 5900, Loss: 5.538e-04, Rel_L2: 5.485e-01, L_inf: 5.485e-01, t/iter: 1.7e-02
#
# Iter 6000, Loss: 2.539e-03, Rel_L2: 5.281e-01, L_inf: 5.281e-01, t/iter: 1.7e-02
#
# Iter 6100, Loss: 5.510e-04, Rel_L2: 5.460e-01, L_inf: 5.460e-01, t/iter: 1.7e-02
#
# Iter 6200, Loss: 5.496e-04, Rel_L2: 5.455e-01, L_inf: 5.455e-01, t/iter: 1.7e-02
#
# Iter 6300, Loss: 5.490e-04, Rel_L2: 5.448e-01, L_inf: 5.448e-01, t/iter: 1.7e-02
#
# Iter 6400, Loss: 5.483e-04, Rel_L2: 5.425e-01, L_inf: 5.425e-01, t/iter: 1.7e-02
#
# Iter 6500, Loss: 5.470e-04, Rel_L2: 5.422e-01, L_inf: 5.422e-01, t/iter: 1.7e-02
#
# Iter 6600, Loss: 5.465e-04, Rel_L2: 5.415e-01, L_inf: 5.415e-01, t/iter: 1.7e-02
#
# Iter 6700, Loss: 5.550e-04, Rel_L2: 5.407e-01, L_inf: 5.407e-01, t/iter: 1.7e-02
#
# Iter 6800, Loss: 5.403e-04, Rel_L2: 5.398e-01, L_inf: 5.398e-01, t/iter: 1.7e-02
#
# Iter 6900, Loss: 5.405e-04, Rel_L2: 5.393e-01, L_inf: 5.393e-01, t/iter: 1.7e-02
#
# Iter 7000, Loss: 5.397e-04, Rel_L2: 5.372e-01, L_inf: 5.372e-01, t/iter: 1.7e-02
#
# Iter 7100, Loss: 5.394e-04, Rel_L2: 5.366e-01, L_inf: 5.366e-01, t/iter: 1.7e-02
#
# Iter 7200, Loss: 5.396e-04, Rel_L2: 5.358e-01, L_inf: 5.358e-01, t/iter: 1.8e-02
#
# Iter 7300, Loss: 7.339e-04, Rel_L2: 5.279e-01, L_inf: 5.279e-01, t/iter: 1.7e-02
#
# Iter 7400, Loss: 5.389e-04, Rel_L2: 5.335e-01, L_inf: 5.335e-01, t/iter: 1.8e-02
#
# Iter 7500, Loss: 5.389e-04, Rel_L2: 5.328e-01, L_inf: 5.328e-01, t/iter: 1.7e-02
#
# Iter 7600, Loss: 7.685e-04, Rel_L2: 5.330e-01, L_inf: 5.330e-01, t/iter: 1.8e-02
#
# Iter 7700, Loss: 5.362e-04, Rel_L2: 5.309e-01, L_inf: 5.309e-01, t/iter: 1.7e-02
#
# Iter 7800, Loss: 5.363e-04, Rel_L2: 5.304e-01, L_inf: 5.304e-01, t/iter: 1.7e-02
#
# Iter 7900, Loss: 5.678e-04, Rel_L2: 5.299e-01, L_inf: 5.299e-01, t/iter: 1.7e-02
#
# Iter 8000, Loss: 5.355e-04, Rel_L2: 5.284e-01, L_inf: 5.284e-01, t/iter: 1.7e-02
#
# Iter 8100, Loss: 5.354e-04, Rel_L2: 5.277e-01, L_inf: 5.277e-01, t/iter: 1.7e-02
#
# Iter 8200, Loss: 5.540e-04, Rel_L2: 5.272e-01, L_inf: 5.272e-01, t/iter: 1.7e-02
#
# Iter 8300, Loss: 5.341e-04, Rel_L2: 5.260e-01, L_inf: 5.260e-01, t/iter: 1.7e-02
#
# Iter 8400, Loss: 5.459e-04, Rel_L2: 5.231e-01, L_inf: 5.231e-01, t/iter: 1.7e-02
#
# Iter 8500, Loss: 5.324e-04, Rel_L2: 5.247e-01, L_inf: 5.247e-01, t/iter: 1.7e-02
#
# Iter 8600, Loss: 5.326e-04, Rel_L2: 5.241e-01, L_inf: 5.241e-01, t/iter: 1.7e-02
#
# Iter 8700, Loss: 1.482e-03, Rel_L2: 5.275e-01, L_inf: 5.275e-01, t/iter: 1.7e-02
#
# Iter 8800, Loss: 5.275e-04, Rel_L2: 5.227e-01, L_inf: 5.227e-01, t/iter: 1.7e-02
#
# Iter 8900, Loss: 5.317e-04, Rel_L2: 5.230e-01, L_inf: 5.230e-01, t/iter: 1.7e-02
#
# Iter 9000, Loss: 5.217e-04, Rel_L2: 5.218e-01, L_inf: 5.218e-01, t/iter: 1.7e-02
#
# Iter 9100, Loss: 5.223e-04, Rel_L2: 5.214e-01, L_inf: 5.214e-01, t/iter: 1.7e-02
#
# Iter 9200, Loss: 5.586e-04, Rel_L2: 5.226e-01, L_inf: 5.226e-01, t/iter: 1.7e-02
#
# Iter 9300, Loss: 5.407e-04, Rel_L2: 5.196e-01, L_inf: 5.196e-01, t/iter: 1.7e-02
#
# Iter 9400, Loss: 6.048e-04, Rel_L2: 5.181e-01, L_inf: 5.181e-01, t/iter: 1.7e-02
#
# Iter 9500, Loss: 6.473e-04, Rel_L2: 5.219e-01, L_inf: 5.219e-01, t/iter: 1.7e-02
#
# Iter 9600, Loss: 5.927e-04, Rel_L2: 5.217e-01, L_inf: 5.217e-01, t/iter: 1.7e-02
#
# Iter 9700, Loss: 9.412e-04, Rel_L2: 5.227e-01, L_inf: 5.227e-01, t/iter: 1.8e-02
#
# Iter 9800, Loss: 5.084e-04, Rel_L2: 5.186e-01, L_inf: 5.186e-01, t/iter: 1.7e-02
#
# Iter 9900, Loss: 9.405e-04, Rel_L2: 5.259e-01, L_inf: 5.259e-01, t/iter: 1.7e-02
#
# Iter 10000, Loss: 5.126e-04, Rel_L2: 5.162e-01, L_inf: 5.162e-01, t/iter: 1.7e-02
#
# Adjusting learning rate of group 0 to 8.1000e-04.
# Iter 10100, Loss: 5.149e-04, Rel_L2: 5.155e-01, L_inf: 5.155e-01, t/iter: 1.7e-02
#
# Iter 10200, Loss: 5.165e-04, Rel_L2: 5.148e-01, L_inf: 5.148e-01, t/iter: 1.7e-02
#
# Iter 10300, Loss: 1.081e-03, Rel_L2: 5.224e-01, L_inf: 5.224e-01, t/iter: 1.7e-02
#
# Iter 10400, Loss: 5.179e-04, Rel_L2: 5.131e-01, L_inf: 5.131e-01, t/iter: 1.7e-02
#
# Iter 10500, Loss: 5.187e-04, Rel_L2: 5.121e-01, L_inf: 5.121e-01, t/iter: 1.7e-02
#
# Iter 10600, Loss: 5.195e-04, Rel_L2: 5.114e-01, L_inf: 5.114e-01, t/iter: 1.7e-02
#
# Iter 10700, Loss: 5.190e-04, Rel_L2: 5.098e-01, L_inf: 5.098e-01, t/iter: 1.7e-02
#
# Iter 10800, Loss: 5.190e-04, Rel_L2: 5.090e-01, L_inf: 5.090e-01, t/iter: 1.7e-02
#
# Iter 10900, Loss: 1.188e-03, Rel_L2: 4.965e-01, L_inf: 4.965e-01, t/iter: 1.7e-02
#
# Iter 11000, Loss: 5.164e-04, Rel_L2: 5.042e-01, L_inf: 5.042e-01, t/iter: 1.7e-02
#
# Iter 11100, Loss: 5.788e-04, Rel_L2: 5.051e-01, L_inf: 5.051e-01, t/iter: 1.7e-02
#
# Iter 11200, Loss: 5.128e-04, Rel_L2: 4.954e-01, L_inf: 4.954e-01, t/iter: 1.7e-02
#
# Iter 11300, Loss: 5.078e-04, Rel_L2: 4.880e-01, L_inf: 4.880e-01, t/iter: 1.7e-02
#
# Iter 11400, Loss: 7.874e-04, Rel_L2: 4.670e-01, L_inf: 4.670e-01, t/iter: 1.7e-02
#
# Iter 11500, Loss: 6.175e-04, Rel_L2: 4.456e-01, L_inf: 4.456e-01, t/iter: 1.7e-02
#
# Iter 11600, Loss: 4.457e-04, Rel_L2: 3.956e-01, L_inf: 3.956e-01, t/iter: 1.7e-02
#
# Iter 11700, Loss: 3.673e-04, Rel_L2: 2.990e-01, L_inf: 2.990e-01, t/iter: 1.7e-02
#
# Iter 11800, Loss: 2.517e-04, Rel_L2: 2.723e-01, L_inf: 2.723e-01, t/iter: 1.7e-02
#
# Iter 11900, Loss: 1.725e-04, Rel_L2: 2.549e-01, L_inf: 2.549e-01, t/iter: 1.7e-02
#
# Iter 12000, Loss: 1.339e-04, Rel_L2: 2.388e-01, L_inf: 2.388e-01, t/iter: 1.7e-02
#
# Iter 12100, Loss: 1.287e-04, Rel_L2: 2.239e-01, L_inf: 2.239e-01, t/iter: 1.7e-02
#
# Iter 12200, Loss: 6.479e-05, Rel_L2: 2.066e-01, L_inf: 2.066e-01, t/iter: 1.7e-02
#
# Iter 12300, Loss: 4.819e-05, Rel_L2: 1.935e-01, L_inf: 1.935e-01, t/iter: 1.7e-02
#
# Iter 12400, Loss: 3.757e-05, Rel_L2: 1.814e-01, L_inf: 1.814e-01, t/iter: 1.7e-02
#
# Iter 12500, Loss: 2.792e-05, Rel_L2: 1.689e-01, L_inf: 1.689e-01, t/iter: 1.7e-02
#
# Iter 12600, Loss: 2.451e-05, Rel_L2: 1.624e-01, L_inf: 1.624e-01, t/iter: 1.7e-02
#
# Iter 12700, Loss: 2.727e-05, Rel_L2: 1.537e-01, L_inf: 1.537e-01, t/iter: 1.7e-02
#
# Iter 12800, Loss: 1.835e-05, Rel_L2: 1.491e-01, L_inf: 1.491e-01, t/iter: 1.7e-02
#
# Iter 12900, Loss: 1.712e-05, Rel_L2: 1.443e-01, L_inf: 1.443e-01, t/iter: 1.7e-02
#
# Iter 13000, Loss: 3.402e-05, Rel_L2: 1.399e-01, L_inf: 1.399e-01, t/iter: 1.7e-02
#
# Iter 13100, Loss: 2.572e-05, Rel_L2: 1.364e-01, L_inf: 1.364e-01, t/iter: 1.7e-02
#
# Iter 13200, Loss: 1.444e-05, Rel_L2: 1.324e-01, L_inf: 1.324e-01, t/iter: 1.7e-02
#
# Iter 13300, Loss: 1.277e-05, Rel_L2: 1.309e-01, L_inf: 1.309e-01, t/iter: 1.7e-02
#
# Iter 13400, Loss: 1.665e-05, Rel_L2: 1.270e-01, L_inf: 1.270e-01, t/iter: 1.7e-02
#
# Iter 13500, Loss: 1.005e-05, Rel_L2: 1.232e-01, L_inf: 1.232e-01, t/iter: 1.7e-02
#
# Iter 13600, Loss: 1.022e-04, Rel_L2: 1.216e-01, L_inf: 1.216e-01, t/iter: 1.7e-02
#
# Iter 13700, Loss: 1.425e-04, Rel_L2: 1.176e-01, L_inf: 1.176e-01, t/iter: 1.7e-02
#
# Iter 13800, Loss: 9.203e-06, Rel_L2: 1.158e-01, L_inf: 1.158e-01, t/iter: 1.7e-02
#
# Iter 13900, Loss: 9.320e-06, Rel_L2: 1.151e-01, L_inf: 1.151e-01, t/iter: 1.7e-02
#
# Iter 14000, Loss: 1.032e-04, Rel_L2: 1.143e-01, L_inf: 1.143e-01, t/iter: 1.7e-02
#
# Iter 28500, Loss: 1.943e-06, Rel_L2: 3.264e-02, L_inf: 3.264e-02, t/iter: 1.7e-02
#
# Iter 28600, Loss: 8.120e-07, Rel_L2: 2.911e-02, L_inf: 2.911e-02, t/iter: 1.7e-02
#
# Iter 28700, Loss: 5.603e-07, Rel_L2: 2.843e-02, L_inf: 2.843e-02, t/iter: 1.7e-02
#
# Iter 28800, Loss: 4.651e-07, Rel_L2: 2.812e-02, L_inf: 2.812e-02, t/iter: 1.7e-02
#
# Iter 28900, Loss: 4.250e-07, Rel_L2: 2.780e-02, L_inf: 2.780e-02, t/iter: 1.7e-02
#
# Iter 29000, Loss: 4.377e-07, Rel_L2: 2.760e-02, L_inf: 2.760e-02, t/iter: 1.7e-02
#
# Iter 29100, Loss: 3.418e-07, Rel_L2: 2.710e-02, L_inf: 2.710e-02, t/iter: 1.7e-02
#
# Iter 29200, Loss: 3.241e-07, Rel_L2: 2.677e-02, L_inf: 2.677e-02, t/iter: 1.7e-02
#
# Iter 29300, Loss: 5.098e-07, Rel_L2: 2.656e-02, L_inf: 2.656e-02, t/iter: 1.7e-02
#
# Iter 29400, Loss: 3.262e-07, Rel_L2: 2.633e-02, L_inf: 2.633e-02, t/iter: 1.7e-02
#
# Iter 29500, Loss: 3.308e-07, Rel_L2: 2.609e-02, L_inf: 2.609e-02, t/iter: 1.7e-02
#
# Iter 29600, Loss: 1.789e-06, Rel_L2: 2.744e-02, L_inf: 2.744e-02, t/iter: 1.7e-02
#
# Iter 29700, Loss: 3.758e-07, Rel_L2: 2.615e-02, L_inf: 2.615e-02, t/iter: 1.7e-02
#
# Iter 29800, Loss: 3.490e-07, Rel_L2: 2.577e-02, L_inf: 2.577e-02, t/iter: 1.7e-02
#
# Iter 29900, Loss: 3.404e-07, Rel_L2: 2.547e-02, L_inf: 2.547e-02, t/iter: 1.7e-02
#
# Iter 30000, Loss: 3.390e-07, Rel_L2: 2.523e-02, L_inf: 2.523e-02, t/iter: 1.7e-02
#
# Adjusting learning rate of group 0 to 5.3144e-04.
# CPU times: user 8min 29s, sys: 3.17 s, total: 8min 33s
# Wall time: 8min 39s

# %%
# %%time
model.train()  # SA
# Out:
# Iter 100, Loss: 3.718e+01, Rel_L2: 6.907e-01, L_inf: 6.907e-01, t/iter: 1.7e-02
#
# Iter 200, Loss: 5.957e+00, Rel_L2: 6.800e-01, L_inf: 6.800e-01, t/iter: 1.7e-02
#
# Iter 300, Loss: 1.519e+00, Rel_L2: 5.803e-01, L_inf: 5.803e-01, t/iter: 1.7e-02
#
# Iter 400, Loss: 1.167e+00, Rel_L2: 6.020e-01, L_inf: 6.020e-01, t/iter: 1.7e-02
#
# Iter 500, Loss: 1.238e+00, Rel_L2: 6.522e-01, L_inf: 6.522e-01, t/iter: 1.7e-02
#
# Iter 600, Loss: 1.348e+00, Rel_L2: 6.914e-01, L_inf: 6.914e-01, t/iter: 1.7e-02
#
# Iter 700, Loss: 1.166e+00, Rel_L2: 7.121e-01, L_inf: 7.121e-01, t/iter: 1.7e-02
#
# Iter 800, Loss: 2.328e+01, Rel_L2: 6.883e-01, L_inf: 6.883e-01, t/iter: 1.7e-02
#
# Iter 900, Loss: 9.951e-01, Rel_L2: 7.590e-01, L_inf: 7.590e-01, t/iter: 1.7e-02
#
# Iter 1000, Loss: 8.259e-01, Rel_L2: 7.898e-01, L_inf: 7.898e-01, t/iter: 1.7e-02
#
# Iter 1100, Loss: 6.358e-01, Rel_L2: 8.186e-01, L_inf: 8.186e-01, t/iter: 1.8e-02
#
# Iter 1200, Loss: 5.957e-01, Rel_L2: 8.290e-01, L_inf: 8.290e-01, t/iter: 1.7e-02
#
# Iter 1300, Loss: 4.501e-01, Rel_L2: 8.396e-01, L_inf: 8.396e-01, t/iter: 1.7e-02
#
# Iter 1400, Loss: 4.102e-01, Rel_L2: 8.478e-01, L_inf: 8.478e-01, t/iter: 1.8e-02
#
# Iter 1500, Loss: 4.151e-01, Rel_L2: 8.491e-01, L_inf: 8.491e-01, t/iter: 1.7e-02
#
# Iter 1600, Loss: 4.048e+00, Rel_L2: 8.265e-01, L_inf: 8.265e-01, t/iter: 1.7e-02
#
# Iter 1700, Loss: 4.878e-01, Rel_L2: 8.223e-01, L_inf: 8.223e-01, t/iter: 1.7e-02
#
# Iter 1800, Loss: 5.188e-01, Rel_L2: 8.178e-01, L_inf: 8.178e-01, t/iter: 1.7e-02
#
# Iter 1900, Loss: 6.060e-01, Rel_L2: 8.085e-01, L_inf: 8.085e-01, t/iter: 1.7e-02
#
# Iter 2000, Loss: 6.109e-01, Rel_L2: 7.999e-01, L_inf: 7.999e-01, t/iter: 1.8e-02
#
# Iter 2100, Loss: 6.655e-01, Rel_L2: 7.901e-01, L_inf: 7.901e-01, t/iter: 1.7e-02
#
# Iter 2200, Loss: 7.541e-01, Rel_L2: 7.731e-01, L_inf: 7.731e-01, t/iter: 1.7e-02
#
# Iter 2300, Loss: 7.873e-01, Rel_L2: 7.722e-01, L_inf: 7.722e-01, t/iter: 1.7e-02
#
# Iter 2400, Loss: 2.448e+00, Rel_L2: 7.561e-01, L_inf: 7.561e-01, t/iter: 1.7e-02
#
# Iter 2500, Loss: 9.048e-01, Rel_L2: 7.581e-01, L_inf: 7.581e-01, t/iter: 1.7e-02
#
# Iter 2600, Loss: 2.663e+00, Rel_L2: 7.352e-01, L_inf: 7.352e-01, t/iter: 1.8e-02
#
# Iter 2700, Loss: 1.018e+00, Rel_L2: 7.439e-01, L_inf: 7.439e-01, t/iter: 1.7e-02
#
# Iter 2800, Loss: 2.485e+00, Rel_L2: 7.287e-01, L_inf: 7.287e-01, t/iter: 1.7e-02
#
# Iter 2900, Loss: 1.140e+00, Rel_L2: 7.322e-01, L_inf: 7.322e-01, t/iter: 1.7e-02
#
# Iter 3000, Loss: 1.156e+00, Rel_L2: 7.226e-01, L_inf: 7.226e-01, t/iter: 1.7e-02
#
# Iter 3100, Loss: 1.348e+00, Rel_L2: 7.165e-01, L_inf: 7.165e-01, t/iter: 1.7e-02
#
# Iter 3200, Loss: 1.464e+00, Rel_L2: 6.994e-01, L_inf: 6.994e-01, t/iter: 1.7e-02
#
# Iter 3300, Loss: 1.302e+00, Rel_L2: 7.016e-01, L_inf: 7.016e-01, t/iter: 1.7e-02
#
# Iter 3400, Loss: 1.530e+00, Rel_L2: 6.879e-01, L_inf: 6.879e-01, t/iter: 1.7e-02
#
# Iter 3500, Loss: 1.333e+00, Rel_L2: 6.800e-01, L_inf: 6.800e-01, t/iter: 1.7e-02
#
# Iter 3600, Loss: 1.321e+00, Rel_L2: 6.738e-01, L_inf: 6.738e-01, t/iter: 1.7e-02
#
# Iter 3700, Loss: 5.192e+00, Rel_L2: 6.446e-01, L_inf: 6.446e-01, t/iter: 1.7e-02
#
# Iter 3800, Loss: 1.370e+00, Rel_L2: 6.580e-01, L_inf: 6.580e-01, t/iter: 1.7e-02
#
# Iter 3900, Loss: 1.551e+00, Rel_L2: 6.433e-01, L_inf: 6.433e-01, t/iter: 1.7e-02
#
# Iter 4000, Loss: 1.395e+00, Rel_L2: 6.397e-01, L_inf: 6.397e-01, t/iter: 1.7e-02
#
# Iter 4100, Loss: 1.498e+00, Rel_L2: 6.330e-01, L_inf: 6.330e-01, t/iter: 1.8e-02
#
# Iter 4200, Loss: 1.375e+00, Rel_L2: 6.248e-01, L_inf: 6.248e-01, t/iter: 1.7e-02
#
# Iter 4300, Loss: 4.491e+00, Rel_L2: 6.418e-01, L_inf: 6.418e-01, t/iter: 1.7e-02
#
# Iter 4400, Loss: 1.365e+00, Rel_L2: 6.138e-01, L_inf: 6.138e-01, t/iter: 1.7e-02
#
# Iter 4500, Loss: 1.353e+00, Rel_L2: 6.084e-01, L_inf: 6.084e-01, t/iter: 1.7e-02
#
# Iter 4600, Loss: 1.541e+00, Rel_L2: 5.977e-01, L_inf: 5.977e-01, t/iter: 1.7e-02
#
# Iter 4700, Loss: 1.462e+00, Rel_L2: 6.017e-01, L_inf: 6.017e-01, t/iter: 1.8e-02
#
# Iter 4800, Loss: 1.423e+00, Rel_L2: 5.819e-01, L_inf: 5.819e-01, t/iter: 1.7e-02
#
# Iter 4900, Loss: 1.330e+00, Rel_L2: 5.896e-01, L_inf: 5.896e-01, t/iter: 1.8e-02
#
# Iter 5000, Loss: 1.285e+00, Rel_L2: 5.803e-01, L_inf: 5.803e-01, t/iter: 1.7e-02
#
# Adjusting learning rate of group 0 to 9.0000e-04.
# Iter 5100, Loss: 1.264e+00, Rel_L2: 5.737e-01, L_inf: 5.737e-01, t/iter: 1.7e-02
#
# Iter 5200, Loss: 1.256e+00, Rel_L2: 5.683e-01, L_inf: 5.683e-01, t/iter: 1.7e-02
#
# Iter 5300, Loss: 1.454e+00, Rel_L2: 5.675e-01, L_inf: 5.675e-01, t/iter: 1.7e-02
#
# Iter 5400, Loss: 1.273e+00, Rel_L2: 5.635e-01, L_inf: 5.635e-01, t/iter: 1.7e-02
#
# Iter 5500, Loss: 1.279e+00, Rel_L2: 5.602e-01, L_inf: 5.602e-01, t/iter: 1.7e-02
#
# Iter 5600, Loss: 1.566e+00, Rel_L2: 5.639e-01, L_inf: 5.639e-01, t/iter: 1.7e-02
#
# Iter 5700, Loss: 1.313e+00, Rel_L2: 5.579e-01, L_inf: 5.579e-01, t/iter: 1.7e-02
#
# Iter 5800, Loss: 1.329e+00, Rel_L2: 5.557e-01, L_inf: 5.557e-01, t/iter: 1.7e-02
#
# Iter 5900, Loss: 1.473e+00, Rel_L2: 5.548e-01, L_inf: 5.548e-01, t/iter: 1.7e-02
#
# Iter 6000, Loss: 1.356e+00, Rel_L2: 5.531e-01, L_inf: 5.531e-01, t/iter: 1.7e-02
#
# Iter 6100, Loss: 2.960e+00, Rel_L2: 5.599e-01, L_inf: 5.599e-01, t/iter: 1.8e-02
#
# Iter 6200, Loss: 1.871e+00, Rel_L2: 5.448e-01, L_inf: 5.448e-01, t/iter: 1.8e-02
#
# Iter 6300, Loss: 1.503e+00, Rel_L2: 5.455e-01, L_inf: 5.455e-01, t/iter: 1.7e-02
#
# Iter 6400, Loss: 2.279e+00, Rel_L2: 5.509e-01, L_inf: 5.509e-01, t/iter: 1.7e-02
#
# Iter 6500, Loss: 2.005e+00, Rel_L2: 5.420e-01, L_inf: 5.420e-01, t/iter: 1.7e-02
#
# Iter 6600, Loss: 1.821e+00, Rel_L2: 5.515e-01, L_inf: 5.515e-01, t/iter: 1.7e-02
#
# Iter 6700, Loss: 1.956e+00, Rel_L2: 5.517e-01, L_inf: 5.517e-01, t/iter: 1.7e-02
#
# Iter 6800, Loss: 1.544e+00, Rel_L2: 5.428e-01, L_inf: 5.428e-01, t/iter: 1.7e-02
#
# Iter 6900, Loss: 2.749e+00, Rel_L2: 5.354e-01, L_inf: 5.354e-01, t/iter: 1.7e-02
#
# Iter 7000, Loss: 1.528e+00, Rel_L2: 5.415e-01, L_inf: 5.415e-01, t/iter: 1.7e-02
#
# Iter 7100, Loss: 1.551e+00, Rel_L2: 5.405e-01, L_inf: 5.405e-01, t/iter: 1.7e-02
#
# Iter 7200, Loss: 3.898e+00, Rel_L2: 5.265e-01, L_inf: 5.265e-01, t/iter: 1.8e-02
#
# Iter 7300, Loss: 1.611e+00, Rel_L2: 5.402e-01, L_inf: 5.402e-01, t/iter: 1.7e-02
#
# Iter 7400, Loss: 1.663e+00, Rel_L2: 5.392e-01, L_inf: 5.392e-01, t/iter: 1.7e-02
#
# Iter 7500, Loss: 1.667e+00, Rel_L2: 5.306e-01, L_inf: 5.306e-01, t/iter: 1.8e-02
#
# Iter 7600, Loss: 1.652e+00, Rel_L2: 5.350e-01, L_inf: 5.350e-01, t/iter: 1.7e-02
#
# Iter 7700, Loss: 2.388e+00, Rel_L2: 5.446e-01, L_inf: 5.446e-01, t/iter: 1.8e-02
#
# Iter 7800, Loss: 1.699e+00, Rel_L2: 5.336e-01, L_inf: 5.336e-01, t/iter: 1.7e-02
#
# Iter 7900, Loss: 1.728e+00, Rel_L2: 5.328e-01, L_inf: 5.328e-01, t/iter: 1.7e-02
#
# Iter 8000, Loss: 1.857e+00, Rel_L2: 5.310e-01, L_inf: 5.310e-01, t/iter: 1.8e-02
#
# Iter 8100, Loss: 1.771e+00, Rel_L2: 5.308e-01, L_inf: 5.308e-01, t/iter: 1.7e-02
#
# Iter 8200, Loss: 1.991e+00, Rel_L2: 5.351e-01, L_inf: 5.351e-01, t/iter: 1.7e-02
#
# Iter 8300, Loss: 5.892e+00, Rel_L2: 5.299e-01, L_inf: 5.299e-01, t/iter: 1.7e-02
#
# Iter 8400, Loss: 1.849e+00, Rel_L2: 5.279e-01, L_inf: 5.279e-01, t/iter: 1.8e-02
#
# Iter 8500, Loss: 2.107e+00, Rel_L2: 5.232e-01, L_inf: 5.232e-01, t/iter: 1.7e-02
#
# Iter 8600, Loss: 1.904e+00, Rel_L2: 5.274e-01, L_inf: 5.274e-01, t/iter: 1.7e-02
#
# Iter 8700, Loss: 1.933e+00, Rel_L2: 5.256e-01, L_inf: 5.256e-01, t/iter: 1.7e-02
#
# Iter 8800, Loss: 3.920e+00, Rel_L2: 5.145e-01, L_inf: 5.145e-01, t/iter: 1.7e-02
#
# Iter 8900, Loss: 2.177e+00, Rel_L2: 5.293e-01, L_inf: 5.293e-01, t/iter: 1.7e-02
#
# Iter 9000, Loss: 2.112e+00, Rel_L2: 5.258e-01, L_inf: 5.258e-01, t/iter: 1.7e-02
#
# Iter 9100, Loss: 7.070e+00, Rel_L2: 5.441e-01, L_inf: 5.441e-01, t/iter: 1.8e-02
#
# Iter 9200, Loss: 2.092e+00, Rel_L2: 5.227e-01, L_inf: 5.227e-01, t/iter: 1.7e-02
#
# Iter 9300, Loss: 2.429e+00, Rel_L2: 5.271e-01, L_inf: 5.271e-01, t/iter: 1.7e-02
#
# Iter 9400, Loss: 5.488e+00, Rel_L2: 5.141e-01, L_inf: 5.141e-01, t/iter: 1.7e-02
#
# Iter 9500, Loss: 2.724e+00, Rel_L2: 5.151e-01, L_inf: 5.151e-01, t/iter: 1.7e-02
#
# Iter 9600, Loss: 3.205e+01, Rel_L2: 5.512e-01, L_inf: 5.512e-01, t/iter: 1.7e-02
#
# Iter 9700, Loss: 9.595e+01, Rel_L2: 8.304e-01, L_inf: 8.304e-01, t/iter: 1.7e-02
#
# Iter 9800, Loss: 1.092e+02, Rel_L2: 8.314e-01, L_inf: 8.314e-01, t/iter: 1.7e-02
#
# Iter 9900, Loss: 1.179e+02, Rel_L2: 8.301e-01, L_inf: 8.301e-01, t/iter: 1.7e-02
#
# Iter 10000, Loss: 1.252e+02, Rel_L2: 8.224e-01, L_inf: 8.224e-01, t/iter: 1.8e-02
#
# Adjusting learning rate of group 0 to 8.1000e-04.
# Iter 10100, Loss: 1.320e+02, Rel_L2: 8.159e-01, L_inf: 8.159e-01, t/iter: 1.8e-02
#
# Iter 10200, Loss: 1.383e+02, Rel_L2: 8.104e-01, L_inf: 8.104e-01, t/iter: 1.7e-02
#
# Iter 10300, Loss: 1.444e+02, Rel_L2: 8.058e-01, L_inf: 8.058e-01, t/iter: 1.7e-02
# Iter 17600, Loss: 4.387e+00, Rel_L2: 5.365e-01, L_inf: 5.365e-01, t/iter: 1.7e-02
#
# Iter 17700, Loss: 4.408e+00, Rel_L2: 5.351e-01, L_inf: 5.351e-01, t/iter: 1.7e-02
#
# Iter 17800, Loss: 4.442e+00, Rel_L2: 5.334e-01, L_inf: 5.334e-01, t/iter: 1.7e-02
#
# Iter 17900, Loss: 4.463e+00, Rel_L2: 5.324e-01, L_inf: 5.324e-01, t/iter: 1.7e-02
#
# Iter 18000, Loss: 4.491e+00, Rel_L2: 5.314e-01, L_inf: 5.314e-01, t/iter: 1.7e-02
#
# Iter 18100, Loss: 4.537e+00, Rel_L2: 5.301e-01, L_inf: 5.301e-01, t/iter: 1.7e-02
#
# Iter 18200, Loss: 4.558e+00, Rel_L2: 5.292e-01, L_inf: 5.292e-01, t/iter: 1.8e-02
#
# Iter 18300, Loss: 4.590e+00, Rel_L2: 5.284e-01, L_inf: 5.284e-01, t/iter: 1.7e-02
#
# Iter 18400, Loss: 4.625e+00, Rel_L2: 5.276e-01, L_inf: 5.276e-01, t/iter: 1.7e-02
#
# Iter 18500, Loss: 4.680e+00, Rel_L2: 5.269e-01, L_inf: 5.269e-01, t/iter: 1.7e-02
#
# Iter 18600, Loss: 4.703e+00, Rel_L2: 5.259e-01, L_inf: 5.259e-01, t/iter: 1.7e-02
#
# Iter 18700, Loss: 4.741e+00, Rel_L2: 5.253e-01, L_inf: 5.253e-01, t/iter: 1.7e-02
#
# Iter 18800, Loss: 4.782e+00, Rel_L2: 5.246e-01, L_inf: 5.246e-01, t/iter: 1.7e-02
#
# Iter 18900, Loss: 4.846e+00, Rel_L2: 5.233e-01, L_inf: 5.233e-01, t/iter: 1.7e-02
#
# Iter 19000, Loss: 4.873e+00, Rel_L2: 5.232e-01, L_inf: 5.232e-01, t/iter: 1.7e-02
#
# Iter 19100, Loss: 4.915e+00, Rel_L2: 5.227e-01, L_inf: 5.227e-01, t/iter: 1.7e-02
#
# Iter 19200, Loss: 4.959e+00, Rel_L2: 5.222e-01, L_inf: 5.222e-01, t/iter: 1.7e-02
#
# Iter 19300, Loss: 5.007e+00, Rel_L2: 5.215e-01, L_inf: 5.215e-01, t/iter: 1.7e-02
#
# Iter 19400, Loss: 5.061e+00, Rel_L2: 5.209e-01, L_inf: 5.209e-01, t/iter: 1.8e-02
#
# Iter 19500, Loss: 5.106e+00, Rel_L2: 5.207e-01, L_inf: 5.207e-01, t/iter: 1.8e-02
#
# Iter 19600, Loss: 5.154e+00, Rel_L2: 5.203e-01, L_inf: 5.203e-01, t/iter: 1.7e-02
#
# Iter 19700, Loss: 5.206e+00, Rel_L2: 5.197e-01, L_inf: 5.197e-01, t/iter: 1.7e-02
#
# Iter 19800, Loss: 5.261e+00, Rel_L2: 5.195e-01, L_inf: 5.195e-01, t/iter: 1.7e-02
#
# Iter 19900, Loss: 5.309e+00, Rel_L2: 5.192e-01, L_inf: 5.192e-01, t/iter: 1.7e-02
#
# Iter 20000, Loss: 5.361e+00, Rel_L2: 5.188e-01, L_inf: 5.188e-01, t/iter: 1.7e-02
#
# Adjusting learning rate of group 0 to 6.5610e-04.
# Iter 20100, Loss: 5.415e+00, Rel_L2: 5.186e-01, L_inf: 5.186e-01, t/iter: 1.8e-02
#
# Iter 20200, Loss: 7.089e+00, Rel_L2: 5.124e-01, L_inf: 5.124e-01, t/iter: 1.7e-02
#
# Iter 20300, Loss: 5.528e+00, Rel_L2: 5.180e-01, L_inf: 5.180e-01, t/iter: 1.7e-02
#
# Iter 20400, Loss: 5.583e+00, Rel_L2: 5.178e-01, L_inf: 5.178e-01, t/iter: 1.7e-02
#
# Iter 20500, Loss: 5.726e+00, Rel_L2: 5.160e-01, L_inf: 5.160e-01, t/iter: 1.8e-02
#
# Iter 20600, Loss: 5.701e+00, Rel_L2: 5.173e-01, L_inf: 5.173e-01, t/iter: 1.7e-02
#
# Iter 20700, Loss: 5.758e+00, Rel_L2: 5.171e-01, L_inf: 5.171e-01, t/iter: 1.7e-02
#
# Iter 20800, Loss: 5.831e+00, Rel_L2: 5.164e-01, L_inf: 5.164e-01, t/iter: 1.7e-02
#
# Iter 20900, Loss: 5.881e+00, Rel_L2: 5.167e-01, L_inf: 5.167e-01, t/iter: 1.8e-02
#
# Iter 21000, Loss: 5.939e+00, Rel_L2: 5.165e-01, L_inf: 5.165e-01, t/iter: 1.8e-02
#
# Iter 21100, Loss: 5.999e+00, Rel_L2: 5.163e-01, L_inf: 5.163e-01, t/iter: 1.7e-02
#
# Iter 21200, Loss: 6.104e+00, Rel_L2: 5.168e-01, L_inf: 5.168e-01, t/iter: 1.7e-02
#
# Iter 21300, Loss: 6.126e+00, Rel_L2: 5.160e-01, L_inf: 5.160e-01, t/iter: 1.7e-02
#
# Iter 21400, Loss: 6.186e+00, Rel_L2: 5.158e-01, L_inf: 5.158e-01, t/iter: 1.7e-02
#
# Iter 21500, Loss: 6.248e+00, Rel_L2: 5.156e-01, L_inf: 5.156e-01, t/iter: 1.7e-02
#
# Iter 21600, Loss: 6.322e+00, Rel_L2: 5.154e-01, L_inf: 5.154e-01, t/iter: 1.8e-02
#
# Iter 21700, Loss: 6.380e+00, Rel_L2: 5.154e-01, L_inf: 5.154e-01, t/iter: 1.7e-02
#
# Iter 21800, Loss: 6.442e+00, Rel_L2: 5.152e-01, L_inf: 5.152e-01, t/iter: 1.8e-02
#
# Iter 21900, Loss: 6.505e+00, Rel_L2: 5.149e-01, L_inf: 5.149e-01, t/iter: 1.7e-02
#
# Iter 22000, Loss: 6.586e+00, Rel_L2: 5.150e-01, L_inf: 5.150e-01, t/iter: 1.8e-02
#
# Iter 22100, Loss: 6.642e+00, Rel_L2: 5.148e-01, L_inf: 5.148e-01, t/iter: 1.7e-02
#
# Iter 22200, Loss: 6.705e+00, Rel_L2: 5.145e-01, L_inf: 5.145e-01, t/iter: 1.7e-02
#
# Iter 22300, Loss: 6.769e+00, Rel_L2: 5.143e-01, L_inf: 5.143e-01, t/iter: 1.7e-02
#
# Iter 22400, Loss: 6.846e+00, Rel_L2: 5.147e-01, L_inf: 5.147e-01, t/iter: 1.7e-02
#
# Iter 22500, Loss: 6.905e+00, Rel_L2: 5.142e-01, L_inf: 5.142e-01, t/iter: 1.7e-02
#
# Iter 22600, Loss: 1.401e+01, Rel_L2: 5.235e-01, L_inf: 5.235e-01, t/iter: 1.8e-02
#
# Iter 22700, Loss: 7.041e+00, Rel_L2: 5.140e-01, L_inf: 5.140e-01, t/iter: 1.7e-02
#
# Iter 22800, Loss: 7.107e+00, Rel_L2: 5.136e-01, L_inf: 5.136e-01, t/iter: 1.7e-02
#
# Iter 22900, Loss: 7.180e+00, Rel_L2: 5.139e-01, L_inf: 5.139e-01, t/iter: 1.8e-02
#
# Iter 23000, Loss: 7.245e+00, Rel_L2: 5.135e-01, L_inf: 5.135e-01, t/iter: 1.7e-02
#
# Iter 23100, Loss: 7.332e+00, Rel_L2: 5.132e-01, L_inf: 5.132e-01, t/iter: 1.7e-02
#
# Iter 23200, Loss: 7.384e+00, Rel_L2: 5.132e-01, L_inf: 5.132e-01, t/iter: 1.7e-02
#
# Iter 23300, Loss: 7.464e+00, Rel_L2: 5.136e-01, L_inf: 5.136e-01, t/iter: 1.7e-02
#
# Iter 23400, Loss: 7.681e+00, Rel_L2: 5.115e-01, L_inf: 5.115e-01, t/iter: 1.8e-02
#
# Iter 23500, Loss: 7.596e+00, Rel_L2: 5.129e-01, L_inf: 5.129e-01, t/iter: 1.7e-02
#
# Iter 23600, Loss: 7.708e+00, Rel_L2: 5.124e-01, L_inf: 5.124e-01, t/iter: 1.7e-02
#
# Iter 23700, Loss: 8.799e+00, Rel_L2: 5.097e-01, L_inf: 5.097e-01, t/iter: 1.7e-02
#
# Iter 23800, Loss: 7.823e+00, Rel_L2: 5.129e-01, L_inf: 5.129e-01, t/iter: 1.7e-02
#
# Iter 23900, Loss: 7.882e+00, Rel_L2: 5.124e-01, L_inf: 5.124e-01, t/iter: 1.7e-02
#
# Iter 24000, Loss: 7.955e+00, Rel_L2: 5.123e-01, L_inf: 5.123e-01, t/iter: 1.7e-02
#
# Iter 24100, Loss: 8.027e+00, Rel_L2: 5.120e-01, L_inf: 5.120e-01, t/iter: 1.7e-02
#
# Iter 24200, Loss: 8.104e+00, Rel_L2: 5.121e-01, L_inf: 5.121e-01, t/iter: 1.7e-02
#
# Iter 24300, Loss: 8.171e+00, Rel_L2: 5.114e-01, L_inf: 5.114e-01, t/iter: 1.8e-02
#
# Iter 24400, Loss: 8.562e+00, Rel_L2: 5.133e-01, L_inf: 5.133e-01, t/iter: 1.7e-02
#
# Iter 24500, Loss: 8.779e+00, Rel_L2: 5.091e-01, L_inf: 5.091e-01, t/iter: 1.7e-02
#
# Iter 24600, Loss: 8.388e+00, Rel_L2: 5.110e-01, L_inf: 5.110e-01, t/iter: 1.7e-02
#
# Iter 24700, Loss: 8.473e+00, Rel_L2: 5.100e-01, L_inf: 5.100e-01, t/iter: 1.8e-02
#
# Iter 24800, Loss: 8.532e+00, Rel_L2: 5.099e-01, L_inf: 5.099e-01, t/iter: 1.8e-02
#
# Iter 24900, Loss: 8.596e+00, Rel_L2: 5.089e-01, L_inf: 5.089e-01, t/iter: 1.7e-02
#
# Iter 25000, Loss: 1.098e+01, Rel_L2: 5.119e-01, L_inf: 5.119e-01, t/iter: 1.7e-02
#
# Adjusting learning rate of group 0 to 5.9049e-04.
# Iter 25100, Loss: 1.068e+01, Rel_L2: 4.955e-01, L_inf: 4.955e-01, t/iter: 1.7e-02
#
# Iter 25200, Loss: 8.766e+00, Rel_L2: 4.935e-01, L_inf: 4.935e-01, t/iter: 1.7e-02
#
# Iter 25300, Loss: 8.657e+00, Rel_L2: 4.823e-01, L_inf: 4.823e-01, t/iter: 1.7e-02
#
# Iter 25400, Loss: 1.723e+01, Rel_L2: 4.849e-01, L_inf: 4.849e-01, t/iter: 1.7e-02
#
# Iter 25500, Loss: 8.304e+00, Rel_L2: 4.203e-01, L_inf: 4.203e-01, t/iter: 1.7e-02
#
# Iter 25600, Loss: 3.703e+00, Rel_L2: 2.505e-01, L_inf: 2.505e-01, t/iter: 1.7e-02
#
# Iter 25700, Loss: 1.162e+00, Rel_L2: 2.260e-01, L_inf: 2.260e-01, t/iter: 1.7e-02
#
# Iter 25800, Loss: 6.157e-01, Rel_L2: 2.050e-01, L_inf: 2.050e-01, t/iter: 1.7e-02
#
# Iter 25900, Loss: 4.634e-01, Rel_L2: 1.922e-01, L_inf: 1.922e-01, t/iter: 1.7e-02
#
# Iter 26000, Loss: 3.115e-01, Rel_L2: 1.812e-01, L_inf: 1.812e-01, t/iter: 1.7e-02
#
# Iter 26100, Loss: 2.609e-01, Rel_L2: 1.734e-01, L_inf: 1.734e-01, t/iter: 1.7e-02
#
# Iter 26200, Loss: 2.080e-01, Rel_L2: 1.649e-01, L_inf: 1.649e-01, t/iter: 1.7e-02
#
# Iter 26300, Loss: 1.882e-01, Rel_L2: 1.599e-01, L_inf: 1.599e-01, t/iter: 1.8e-02
#
# Iter 26400, Loss: 1.598e-01, Rel_L2: 1.539e-01, L_inf: 1.539e-01, t/iter: 1.8e-02
#
# Iter 26500, Loss: 1.686e-01, Rel_L2: 1.505e-01, L_inf: 1.505e-01, t/iter: 1.7e-02
#
# Iter 26600, Loss: 1.302e-01, Rel_L2: 1.455e-01, L_inf: 1.455e-01, t/iter: 1.7e-02
#
# Iter 26700, Loss: 1.896e-01, Rel_L2: 1.435e-01, L_inf: 1.435e-01, t/iter: 1.7e-02
#
# Iter 26800, Loss: 1.104e-01, Rel_L2: 1.385e-01, L_inf: 1.385e-01, t/iter: 1.8e-02
#
# Iter 26900, Loss: 9.979e-02, Rel_L2: 1.349e-01, L_inf: 1.349e-01, t/iter: 1.7e-02
#
# Iter 27000, Loss: 1.093e-01, Rel_L2: 1.331e-01, L_inf: 1.331e-01, t/iter: 1.7e-02
#
# Iter 27100, Loss: 8.779e-02, Rel_L2: 1.293e-01, L_inf: 1.293e-01, t/iter: 1.7e-02
# Iter 29600, Loss: 3.253e-02, Rel_L2: 8.217e-02, L_inf: 8.217e-02, t/iter: 1.7e-02
#
# Iter 29700, Loss: 4.340e-02, Rel_L2: 8.115e-02, L_inf: 8.115e-02, t/iter: 1.8e-02
#
# Iter 29800, Loss: 2.388e-02, Rel_L2: 8.000e-02, L_inf: 8.000e-02, t/iter: 1.7e-02
#
# Iter 29900, Loss: 2.543e-02, Rel_L2: 7.924e-02, L_inf: 7.924e-02, t/iter: 1.7e-02
#
# Iter 30000, Loss: 7.105e-02, Rel_L2: 7.855e-02, L_inf: 7.855e-02, t/iter: 1.7e-02
#
# Adjusting learning rate of group 0 to 5.3144e-04.
# CPU times: user 8min 35s, sys: 3.12 s, total: 8min 38s
# Wall time: 8min 44s

# %%
# %%time
model.train()  # Vanilla
# Out:
# Iter 100, Loss: 1.419e-01, Rel_L2: 9.998e-01, L_inf: 9.998e-01, t/iter: 1.7e-02
#
# Iter 200, Loss: 1.399e-01, Rel_L2: 9.964e-01, L_inf: 9.964e-01, t/iter: 1.7e-02
#
# Iter 300, Loss: 1.386e-01, Rel_L2: 9.936e-01, L_inf: 9.936e-01, t/iter: 1.7e-02
#
# Iter 400, Loss: 1.377e-01, Rel_L2: 9.910e-01, L_inf: 9.910e-01, t/iter: 1.7e-02
#
# Iter 500, Loss: 1.371e-01, Rel_L2: 9.889e-01, L_inf: 9.889e-01, t/iter: 1.7e-02
#
# Iter 600, Loss: 1.368e-01, Rel_L2: 9.873e-01, L_inf: 9.873e-01, t/iter: 1.7e-02
#
# Iter 700, Loss: 1.367e-01, Rel_L2: 9.863e-01, L_inf: 9.863e-01, t/iter: 1.7e-02
#
# Iter 800, Loss: 1.365e-01, Rel_L2: 9.859e-01, L_inf: 9.859e-01, t/iter: 1.7e-02
#
# Iter 900, Loss: 1.364e-01, Rel_L2: 9.857e-01, L_inf: 9.857e-01, t/iter: 1.7e-02
#
# Iter 1000, Loss: 1.363e-01, Rel_L2: 9.857e-01, L_inf: 9.857e-01, t/iter: 1.7e-02
#
# Iter 1100, Loss: 1.362e-01, Rel_L2: 9.857e-01, L_inf: 9.857e-01, t/iter: 1.7e-02
#
# Iter 1200, Loss: 1.361e-01, Rel_L2: 9.858e-01, L_inf: 9.858e-01, t/iter: 1.7e-02
#
# Iter 1300, Loss: 1.360e-01, Rel_L2: 9.860e-01, L_inf: 9.860e-01, t/iter: 1.7e-02
#
# Iter 1400, Loss: 1.358e-01, Rel_L2: 9.861e-01, L_inf: 9.861e-01, t/iter: 1.7e-02
#
# Iter 1500, Loss: 1.357e-01, Rel_L2: 9.864e-01, L_inf: 9.864e-01, t/iter: 1.7e-02
#
# Iter 1600, Loss: 1.355e-01, Rel_L2: 9.867e-01, L_inf: 9.867e-01, t/iter: 1.7e-02
#
# Iter 1700, Loss: 1.352e-01, Rel_L2: 9.871e-01, L_inf: 9.871e-01, t/iter: 1.7e-02
#
# Iter 1800, Loss: 1.349e-01, Rel_L2: 9.877e-01, L_inf: 9.877e-01, t/iter: 1.7e-02
#
# Iter 1900, Loss: 1.345e-01, Rel_L2: 9.885e-01, L_inf: 9.885e-01, t/iter: 1.7e-02
#
# Iter 2000, Loss: 1.341e-01, Rel_L2: 9.897e-01, L_inf: 9.897e-01, t/iter: 1.7e-02
#
# Iter 2100, Loss: 1.336e-01, Rel_L2: 9.911e-01, L_inf: 9.911e-01, t/iter: 1.7e-02
#
# Iter 2200, Loss: 1.331e-01, Rel_L2: 9.927e-01, L_inf: 9.927e-01, t/iter: 1.7e-02
#
# Iter 2300, Loss: 1.328e-01, Rel_L2: 9.942e-01, L_inf: 9.942e-01, t/iter: 1.7e-02
#
# Iter 2400, Loss: 1.325e-01, Rel_L2: 9.953e-01, L_inf: 9.953e-01, t/iter: 1.7e-02
#
# Iter 2500, Loss: 1.324e-01, Rel_L2: 9.959e-01, L_inf: 9.959e-01, t/iter: 1.7e-02
#
# Iter 2600, Loss: 1.323e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 2700, Loss: 1.322e-01, Rel_L2: 9.963e-01, L_inf: 9.963e-01, t/iter: 1.7e-02
#
# Iter 2800, Loss: 1.321e-01, Rel_L2: 9.963e-01, L_inf: 9.963e-01, t/iter: 1.7e-02
#
# Iter 2900, Loss: 1.321e-01, Rel_L2: 9.963e-01, L_inf: 9.963e-01, t/iter: 1.7e-02
#
# Iter 3000, Loss: 1.320e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 3100, Loss: 1.319e-01, Rel_L2: 9.961e-01, L_inf: 9.961e-01, t/iter: 1.7e-02
#
# Iter 3200, Loss: 1.318e-01, Rel_L2: 9.960e-01, L_inf: 9.960e-01, t/iter: 1.7e-02
#
# Iter 3300, Loss: 1.317e-01, Rel_L2: 9.959e-01, L_inf: 9.959e-01, t/iter: 1.7e-02
#
# Iter 3400, Loss: 1.316e-01, Rel_L2: 9.957e-01, L_inf: 9.957e-01, t/iter: 1.7e-02
#
# Iter 3500, Loss: 1.314e-01, Rel_L2: 9.955e-01, L_inf: 9.955e-01, t/iter: 1.7e-02
#
# Iter 3600, Loss: 1.313e-01, Rel_L2: 9.953e-01, L_inf: 9.953e-01, t/iter: 1.7e-02
#
# Iter 3700, Loss: 1.312e-01, Rel_L2: 9.946e-01, L_inf: 9.946e-01, t/iter: 1.7e-02
#
# Iter 3800, Loss: 1.310e-01, Rel_L2: 9.946e-01, L_inf: 9.946e-01, t/iter: 1.7e-02
#
# Iter 3900, Loss: 1.308e-01, Rel_L2: 9.942e-01, L_inf: 9.942e-01, t/iter: 1.7e-02
#
# Iter 4000, Loss: 1.306e-01, Rel_L2: 9.937e-01, L_inf: 9.937e-01, t/iter: 1.7e-02
#
# Iter 4100, Loss: 1.305e-01, Rel_L2: 9.929e-01, L_inf: 9.929e-01, t/iter: 1.7e-02
#
# Iter 4200, Loss: 1.305e-01, Rel_L2: 9.923e-01, L_inf: 9.923e-01, t/iter: 1.7e-02
#
# Iter 4300, Loss: 1.304e-01, Rel_L2: 9.922e-01, L_inf: 9.922e-01, t/iter: 1.7e-02
#
# Iter 4400, Loss: 1.303e-01, Rel_L2: 9.920e-01, L_inf: 9.920e-01, t/iter: 1.7e-02
#
# Iter 4500, Loss: 1.302e-01, Rel_L2: 9.919e-01, L_inf: 9.919e-01, t/iter: 1.7e-02
#
# Iter 4600, Loss: 1.314e-01, Rel_L2: 9.943e-01, L_inf: 9.943e-01, t/iter: 1.7e-02
#
# Iter 4700, Loss: 1.303e-01, Rel_L2: 9.917e-01, L_inf: 9.917e-01, t/iter: 1.7e-02
#
# Iter 4800, Loss: 1.302e-01, Rel_L2: 9.917e-01, L_inf: 9.917e-01, t/iter: 1.7e-02
#
# Iter 4900, Loss: 1.302e-01, Rel_L2: 9.917e-01, L_inf: 9.917e-01, t/iter: 1.7e-02
#
# Iter 5000, Loss: 1.301e-01, Rel_L2: 9.918e-01, L_inf: 9.918e-01, t/iter: 1.7e-02
#
# Adjusting learning rate of group 0 to 9.0000e-04.
# Iter 5100, Loss: 1.301e-01, Rel_L2: 9.919e-01, L_inf: 9.919e-01, t/iter: 1.7e-02
#
# Iter 5200, Loss: 1.301e-01, Rel_L2: 9.922e-01, L_inf: 9.922e-01, t/iter: 1.7e-02
#
# Iter 5300, Loss: 1.302e-01, Rel_L2: 9.918e-01, L_inf: 9.918e-01, t/iter: 1.7e-02
#
# Iter 5400, Loss: 1.301e-01, Rel_L2: 9.919e-01, L_inf: 9.919e-01, t/iter: 1.7e-02
#
# Iter 5500, Loss: 1.301e-01, Rel_L2: 9.920e-01, L_inf: 9.920e-01, t/iter: 1.7e-02
#
# Iter 5600, Loss: 1.300e-01, Rel_L2: 9.921e-01, L_inf: 9.921e-01, t/iter: 1.7e-02
#
# Iter 5700, Loss: 1.304e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 5800, Loss: 1.301e-01, Rel_L2: 9.921e-01, L_inf: 9.921e-01, t/iter: 1.7e-02
#
# Iter 5900, Loss: 1.300e-01, Rel_L2: 9.922e-01, L_inf: 9.922e-01, t/iter: 1.7e-02
#
# Iter 6000, Loss: 1.300e-01, Rel_L2: 9.924e-01, L_inf: 9.924e-01, t/iter: 1.7e-02
#
# Iter 6100, Loss: 1.304e-01, Rel_L2: 9.906e-01, L_inf: 9.906e-01, t/iter: 1.7e-02
#
# Iter 6200, Loss: 1.301e-01, Rel_L2: 9.923e-01, L_inf: 9.923e-01, t/iter: 1.7e-02
#
# Iter 6300, Loss: 1.300e-01, Rel_L2: 9.924e-01, L_inf: 9.924e-01, t/iter: 1.7e-02
#
# Iter 6400, Loss: 1.300e-01, Rel_L2: 9.926e-01, L_inf: 9.926e-01, t/iter: 1.7e-02
#
# Iter 6500, Loss: 1.525e-01, Rel_L2: 9.856e-01, L_inf: 9.856e-01, t/iter: 1.7e-02
#
# Iter 6600, Loss: 1.300e-01, Rel_L2: 9.927e-01, L_inf: 9.927e-01, t/iter: 1.7e-02
#
# Iter 6700, Loss: 1.300e-01, Rel_L2: 9.928e-01, L_inf: 9.928e-01, t/iter: 1.7e-02
#
# Iter 6800, Loss: 1.299e-01, Rel_L2: 9.930e-01, L_inf: 9.930e-01, t/iter: 1.7e-02
#
# Iter 6900, Loss: 1.301e-01, Rel_L2: 9.931e-01, L_inf: 9.931e-01, t/iter: 1.7e-02
#
# Iter 7000, Loss: 1.300e-01, Rel_L2: 9.929e-01, L_inf: 9.929e-01, t/iter: 1.7e-02
#
# Iter 7100, Loss: 1.299e-01, Rel_L2: 9.931e-01, L_inf: 9.931e-01, t/iter: 1.7e-02
#
# Iter 7200, Loss: 1.346e-01, Rel_L2: 9.935e-01, L_inf: 9.935e-01, t/iter: 1.7e-02
#
# Iter 7300, Loss: 1.300e-01, Rel_L2: 9.930e-01, L_inf: 9.930e-01, t/iter: 1.7e-02
#
# Iter 7400, Loss: 1.299e-01, Rel_L2: 9.931e-01, L_inf: 9.931e-01, t/iter: 1.7e-02
#
# Iter 7500, Loss: 1.299e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 7600, Loss: 1.314e-01, Rel_L2: 9.968e-01, L_inf: 9.968e-01, t/iter: 1.7e-02
#
# Iter 7700, Loss: 1.299e-01, Rel_L2: 9.932e-01, L_inf: 9.932e-01, t/iter: 1.7e-02
#
# Iter 7800, Loss: 1.299e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 7900, Loss: 1.301e-01, Rel_L2: 9.922e-01, L_inf: 9.922e-01, t/iter: 1.7e-02
#
# Iter 8000, Loss: 1.299e-01, Rel_L2: 9.929e-01, L_inf: 9.929e-01, t/iter: 1.7e-02
#
# Iter 8100, Loss: 1.299e-01, Rel_L2: 9.931e-01, L_inf: 9.931e-01, t/iter: 1.7e-02
#
# Iter 8200, Loss: 1.358e-01, Rel_L2: 9.986e-01, L_inf: 9.986e-01, t/iter: 1.7e-02
#
# Iter 8300, Loss: 1.299e-01, Rel_L2: 9.932e-01, L_inf: 9.932e-01, t/iter: 1.7e-02
#
# Iter 8400, Loss: 1.485e-01, Rel_L2: 9.832e-01, L_inf: 9.832e-01, t/iter: 1.7e-02
#
# Iter 8500, Loss: 1.299e-01, Rel_L2: 9.931e-01, L_inf: 9.931e-01, t/iter: 1.7e-02
#
# Iter 8600, Loss: 1.298e-01, Rel_L2: 9.931e-01, L_inf: 9.931e-01, t/iter: 1.7e-02
#
# Iter 8700, Loss: 1.299e-01, Rel_L2: 9.927e-01, L_inf: 9.927e-01, t/iter: 1.7e-02
#
# Iter 8800, Loss: 1.298e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 8900, Loss: 1.300e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 9000, Loss: 1.298e-01, Rel_L2: 9.929e-01, L_inf: 9.929e-01, t/iter: 1.7e-02
#
# Iter 9100, Loss: 1.300e-01, Rel_L2: 9.920e-01, L_inf: 9.920e-01, t/iter: 1.7e-02
#
# Iter 9200, Loss: 1.298e-01, Rel_L2: 9.929e-01, L_inf: 9.929e-01, t/iter: 1.7e-02
#
# Iter 9300, Loss: 1.299e-01, Rel_L2: 9.930e-01, L_inf: 9.930e-01, t/iter: 1.7e-02
#
# Iter 9400, Loss: 1.298e-01, Rel_L2: 9.930e-01, L_inf: 9.930e-01, t/iter: 1.7e-02
#
# Iter 9500, Loss: 1.298e-01, Rel_L2: 9.929e-01, L_inf: 9.929e-01, t/iter: 1.7e-02
#
# Iter 9600, Loss: 1.308e-01, Rel_L2: 9.907e-01, L_inf: 9.907e-01, t/iter: 1.7e-02
#
# Iter 9700, Loss: 1.298e-01, Rel_L2: 9.926e-01, L_inf: 9.926e-01, t/iter: 1.7e-02
#
# Iter 9800, Loss: 1.298e-01, Rel_L2: 9.926e-01, L_inf: 9.926e-01, t/iter: 1.7e-02
#
# Iter 9900, Loss: 1.298e-01, Rel_L2: 9.930e-01, L_inf: 9.930e-01, t/iter: 1.7e-02
#
# Iter 10000, Loss: 1.298e-01, Rel_L2: 9.927e-01, L_inf: 9.927e-01, t/iter: 1.7e-02
#
# Adjusting learning rate of group 0 to 8.1000e-04.
# Iter 10100, Loss: 1.298e-01, Rel_L2: 9.926e-01, L_inf: 9.926e-01, t/iter: 1.7e-02
#
# Iter 10200, Loss: 1.298e-01, Rel_L2: 9.927e-01, L_inf: 9.927e-01, t/iter: 1.7e-02
#
# Iter 10300, Loss: 1.298e-01, Rel_L2: 9.926e-01, L_inf: 9.926e-01, t/iter: 1.7e-02
#
# Iter 10400, Loss: 1.298e-01, Rel_L2: 9.926e-01, L_inf: 9.926e-01, t/iter: 1.7e-02
#
# Iter 10500, Loss: 1.298e-01, Rel_L2: 9.928e-01, L_inf: 9.928e-01, t/iter: 1.7e-02
#
# Iter 10600, Loss: 1.298e-01, Rel_L2: 9.925e-01, L_inf: 9.925e-01, t/iter: 1.7e-02
#
# Iter 10700, Loss: 1.298e-01, Rel_L2: 9.926e-01, L_inf: 9.926e-01, t/iter: 1.7e-02
#
# Iter 10800, Loss: 1.332e-01, Rel_L2: 9.971e-01, L_inf: 9.971e-01, t/iter: 1.7e-02
#
# Iter 10900, Loss: 1.298e-01, Rel_L2: 9.926e-01, L_inf: 9.926e-01, t/iter: 1.7e-02
#
# Iter 11000, Loss: 1.298e-01, Rel_L2: 9.925e-01, L_inf: 9.925e-01, t/iter: 1.7e-02
#
# Iter 11100, Loss: 1.304e-01, Rel_L2: 9.910e-01, L_inf: 9.910e-01, t/iter: 1.7e-02
#
# Iter 11200, Loss: 1.298e-01, Rel_L2: 9.923e-01, L_inf: 9.923e-01, t/iter: 1.7e-02
#
# Iter 11300, Loss: 1.298e-01, Rel_L2: 9.924e-01, L_inf: 9.924e-01, t/iter: 1.7e-02
#
# Iter 11400, Loss: 3.248e+00, Rel_L2: 1.092e+00, L_inf: 1.092e+00, t/iter: 1.7e-02
#
# Iter 11500, Loss: 1.772e-01, Rel_L2: 9.821e-01, L_inf: 9.821e-01, t/iter: 1.7e-02
#
# Iter 11600, Loss: 1.415e-01, Rel_L2: 9.963e-01, L_inf: 9.963e-01, t/iter: 1.7e-02
#
# Iter 11700, Loss: 1.415e-01, Rel_L2: 9.963e-01, L_inf: 9.963e-01, t/iter: 1.7e-02
#
# Iter 11800, Loss: 1.415e-01, Rel_L2: 9.963e-01, L_inf: 9.963e-01, t/iter: 1.7e-02
#
# Iter 11900, Loss: 1.415e-01, Rel_L2: 9.963e-01, L_inf: 9.963e-01, t/iter: 1.7e-02
#
# Iter 12000, Loss: 1.415e-01, Rel_L2: 9.963e-01, L_inf: 9.963e-01, t/iter: 1.7e-02
#
# Iter 12100, Loss: 1.415e-01, Rel_L2: 9.963e-01, L_inf: 9.963e-01, t/iter: 1.7e-02
#
# Iter 12200, Loss: 1.415e-01, Rel_L2: 9.963e-01, L_inf: 9.963e-01, t/iter: 1.7e-02
#
# Iter 12300, Loss: 1.415e-01, Rel_L2: 9.963e-01, L_inf: 9.963e-01, t/iter: 1.7e-02
#
# Iter 12400, Loss: 1.414e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 12500, Loss: 1.414e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 12600, Loss: 1.414e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 12700, Loss: 1.414e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 12800, Loss: 1.414e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 12900, Loss: 1.414e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 13000, Loss: 1.413e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 13100, Loss: 1.413e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 13200, Loss: 1.413e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 13300, Loss: 1.413e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 13400, Loss: 1.413e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 13500, Loss: 1.412e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 13600, Loss: 1.412e-01, Rel_L2: 9.962e-01, L_inf: 9.962e-01, t/iter: 1.7e-02
#
# Iter 13700, Loss: 1.412e-01, Rel_L2: 9.961e-01, L_inf: 9.961e-01, t/iter: 1.7e-02
#
# Iter 13800, Loss: 1.412e-01, Rel_L2: 9.961e-01, L_inf: 9.961e-01, t/iter: 1.7e-02
#
# Iter 13900, Loss: 1.411e-01, Rel_L2: 9.961e-01, L_inf: 9.961e-01, t/iter: 1.7e-02
#
# Iter 14000, Loss: 1.411e-01, Rel_L2: 9.961e-01, L_inf: 9.961e-01, t/iter: 1.7e-02
#
# Iter 14100, Loss: 1.411e-01, Rel_L2: 9.961e-01, L_inf: 9.961e-01, t/iter: 1.7e-02
#
# Iter 14200, Loss: 1.411e-01, Rel_L2: 9.961e-01, L_inf: 9.961e-01, t/iter: 1.7e-02
#
# Iter 14300, Loss: 1.410e-01, Rel_L2: 9.961e-01, L_inf: 9.961e-01, t/iter: 1.7e-02
#
# Iter 14400, Loss: 1.410e-01, Rel_L2: 9.961e-01, L_inf: 9.961e-01, t/iter: 1.7e-02
#
# Iter 14500, Loss: 1.410e-01, Rel_L2: 9.961e-01, L_inf: 9.961e-01, t/iter: 1.7e-02
#
# Iter 14600, Loss: 1.409e-01, Rel_L2: 9.960e-01, L_inf: 9.960e-01, t/iter: 1.7e-02
#
# Iter 14700, Loss: 1.409e-01, Rel_L2: 9.960e-01, L_inf: 9.960e-01, t/iter: 1.7e-02
#
# Iter 14800, Loss: 1.409e-01, Rel_L2: 9.960e-01, L_inf: 9.960e-01, t/iter: 1.7e-02
#
# Iter 14900, Loss: 1.408e-01, Rel_L2: 9.960e-01, L_inf: 9.960e-01, t/iter: 1.7e-02
#
# Iter 15000, Loss: 1.408e-01, Rel_L2: 9.960e-01, L_inf: 9.960e-01, t/iter: 1.7e-02
#
# Adjusting learning rate of group 0 to 7.2900e-04.
# Iter 15100, Loss: 1.408e-01, Rel_L2: 9.960e-01, L_inf: 9.960e-01, t/iter: 1.7e-02
#
# Iter 15200, Loss: 1.407e-01, Rel_L2: 9.960e-01, L_inf: 9.960e-01, t/iter: 1.7e-02
#
# Iter 15300, Loss: 1.407e-01, Rel_L2: 9.959e-01, L_inf: 9.959e-01, t/iter: 1.7e-02
#
# Iter 15400, Loss: 1.407e-01, Rel_L2: 9.959e-01, L_inf: 9.959e-01, t/iter: 1.8e-02
#
# Iter 15500, Loss: 1.406e-01, Rel_L2: 9.959e-01, L_inf: 9.959e-01, t/iter: 1.7e-02
#
# Iter 15600, Loss: 1.406e-01, Rel_L2: 9.959e-01, L_inf: 9.959e-01, t/iter: 1.7e-02
#
# Iter 15700, Loss: 1.405e-01, Rel_L2: 9.959e-01, L_inf: 9.959e-01, t/iter: 1.7e-02
#
# Iter 15800, Loss: 1.405e-01, Rel_L2: 9.959e-01, L_inf: 9.959e-01, t/iter: 1.7e-02
#
# Iter 15900, Loss: 1.404e-01, Rel_L2: 9.958e-01, L_inf: 9.958e-01, t/iter: 1.7e-02
#
# Iter 16000, Loss: 1.404e-01, Rel_L2: 9.958e-01, L_inf: 9.958e-01, t/iter: 1.7e-02
#
# Iter 16100, Loss: 1.404e-01, Rel_L2: 9.958e-01, L_inf: 9.958e-01, t/iter: 1.7e-02
#
# Iter 16200, Loss: 1.403e-01, Rel_L2: 9.958e-01, L_inf: 9.958e-01, t/iter: 1.7e-02
#
# Iter 16300, Loss: 1.403e-01, Rel_L2: 9.957e-01, L_inf: 9.957e-01, t/iter: 1.7e-02
#
# Iter 16400, Loss: 1.402e-01, Rel_L2: 9.957e-01, L_inf: 9.957e-01, t/iter: 1.7e-02
#
# Iter 16500, Loss: 1.402e-01, Rel_L2: 9.957e-01, L_inf: 9.957e-01, t/iter: 1.7e-02
#
# Iter 16600, Loss: 1.401e-01, Rel_L2: 9.957e-01, L_inf: 9.957e-01, t/iter: 1.7e-02
#
# Iter 16700, Loss: 1.400e-01, Rel_L2: 9.956e-01, L_inf: 9.956e-01, t/iter: 1.7e-02
#
# Iter 16800, Loss: 1.400e-01, Rel_L2: 9.956e-01, L_inf: 9.956e-01, t/iter: 1.7e-02
#
# Iter 16900, Loss: 1.399e-01, Rel_L2: 9.956e-01, L_inf: 9.956e-01, t/iter: 1.7e-02
#
# Iter 17000, Loss: 1.399e-01, Rel_L2: 9.955e-01, L_inf: 9.955e-01, t/iter: 1.7e-02
#
# Iter 17100, Loss: 1.398e-01, Rel_L2: 9.955e-01, L_inf: 9.955e-01, t/iter: 1.7e-02
#
# Iter 17200, Loss: 1.397e-01, Rel_L2: 9.955e-01, L_inf: 9.955e-01, t/iter: 1.7e-02
#
# Iter 17300, Loss: 1.397e-01, Rel_L2: 9.954e-01, L_inf: 9.954e-01, t/iter: 1.7e-02
#
# Iter 17400, Loss: 1.396e-01, Rel_L2: 9.954e-01, L_inf: 9.954e-01, t/iter: 1.7e-02
#
# Iter 17500, Loss: 1.395e-01, Rel_L2: 9.953e-01, L_inf: 9.953e-01, t/iter: 1.7e-02
#
# Iter 17600, Loss: 1.394e-01, Rel_L2: 9.953e-01, L_inf: 9.953e-01, t/iter: 1.7e-02
#
# Iter 17700, Loss: 1.393e-01, Rel_L2: 9.952e-01, L_inf: 9.952e-01, t/iter: 1.7e-02
#
# Iter 17800, Loss: 1.393e-01, Rel_L2: 9.952e-01, L_inf: 9.952e-01, t/iter: 1.7e-02
#
# Iter 17900, Loss: 1.392e-01, Rel_L2: 9.951e-01, L_inf: 9.951e-01, t/iter: 1.7e-02
#
# Iter 18000, Loss: 1.391e-01, Rel_L2: 9.951e-01, L_inf: 9.951e-01, t/iter: 1.7e-02
#
# Iter 18100, Loss: 1.390e-01, Rel_L2: 9.950e-01, L_inf: 9.950e-01, t/iter: 1.7e-02
#
# Iter 18200, Loss: 1.389e-01, Rel_L2: 9.949e-01, L_inf: 9.949e-01, t/iter: 1.7e-02
#
# Iter 18300, Loss: 1.388e-01, Rel_L2: 9.949e-01, L_inf: 9.949e-01, t/iter: 1.7e-02
#
# Iter 18400, Loss: 1.387e-01, Rel_L2: 9.948e-01, L_inf: 9.948e-01, t/iter: 1.7e-02
#
# Iter 18500, Loss: 1.387e-01, Rel_L2: 9.947e-01, L_inf: 9.947e-01, t/iter: 1.7e-02
#
# Iter 18600, Loss: 1.386e-01, Rel_L2: 9.946e-01, L_inf: 9.946e-01, t/iter: 1.7e-02
#
# Iter 18700, Loss: 1.385e-01, Rel_L2: 9.945e-01, L_inf: 9.945e-01, t/iter: 1.7e-02
#
# Iter 18800, Loss: 1.384e-01, Rel_L2: 9.944e-01, L_inf: 9.944e-01, t/iter: 1.7e-02
#
# Iter 18900, Loss: 1.383e-01, Rel_L2: 9.943e-01, L_inf: 9.943e-01, t/iter: 1.7e-02
#
# Iter 19000, Loss: 1.382e-01, Rel_L2: 9.942e-01, L_inf: 9.942e-01, t/iter: 1.7e-02
#
# Iter 19100, Loss: 1.381e-01, Rel_L2: 9.941e-01, L_inf: 9.941e-01, t/iter: 1.7e-02
#
# Iter 19200, Loss: 1.380e-01, Rel_L2: 9.939e-01, L_inf: 9.939e-01, t/iter: 1.7e-02
#
# Iter 19300, Loss: 1.379e-01, Rel_L2: 9.938e-01, L_inf: 9.938e-01, t/iter: 1.7e-02
#
# Iter 19400, Loss: 1.378e-01, Rel_L2: 9.936e-01, L_inf: 9.936e-01, t/iter: 1.7e-02
#
# Iter 19500, Loss: 1.377e-01, Rel_L2: 9.935e-01, L_inf: 9.935e-01, t/iter: 1.7e-02
#
# Iter 19600, Loss: 1.376e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 19700, Loss: 1.375e-01, Rel_L2: 9.931e-01, L_inf: 9.931e-01, t/iter: 1.7e-02
#
# Iter 19800, Loss: 1.374e-01, Rel_L2: 9.928e-01, L_inf: 9.928e-01, t/iter: 1.7e-02
#
# Iter 19900, Loss: 1.373e-01, Rel_L2: 9.926e-01, L_inf: 9.926e-01, t/iter: 1.7e-02
#
# Iter 20000, Loss: 1.372e-01, Rel_L2: 9.923e-01, L_inf: 9.923e-01, t/iter: 1.7e-02
#
# Adjusting learning rate of group 0 to 6.5610e-04.
# Iter 20100, Loss: 1.372e-01, Rel_L2: 9.921e-01, L_inf: 9.921e-01, t/iter: 1.7e-02
#
# Iter 20200, Loss: 1.371e-01, Rel_L2: 9.918e-01, L_inf: 9.918e-01, t/iter: 1.7e-02
#
# Iter 20300, Loss: 1.370e-01, Rel_L2: 9.915e-01, L_inf: 9.915e-01, t/iter: 1.7e-02
#
# Iter 20400, Loss: 1.369e-01, Rel_L2: 9.912e-01, L_inf: 9.912e-01, t/iter: 1.7e-02
#
# Iter 20500, Loss: 1.368e-01, Rel_L2: 9.909e-01, L_inf: 9.909e-01, t/iter: 1.7e-02
#
# Iter 20600, Loss: 1.367e-01, Rel_L2: 9.905e-01, L_inf: 9.905e-01, t/iter: 1.7e-02
#
# Iter 20700, Loss: 1.367e-01, Rel_L2: 9.902e-01, L_inf: 9.902e-01, t/iter: 1.7e-02
#
# Iter 20800, Loss: 1.366e-01, Rel_L2: 9.898e-01, L_inf: 9.898e-01, t/iter: 1.7e-02
#
# Iter 20900, Loss: 1.365e-01, Rel_L2: 9.895e-01, L_inf: 9.895e-01, t/iter: 1.7e-02
#
# Iter 21000, Loss: 1.364e-01, Rel_L2: 9.891e-01, L_inf: 9.891e-01, t/iter: 1.7e-02
#
# Iter 21100, Loss: 1.364e-01, Rel_L2: 9.888e-01, L_inf: 9.888e-01, t/iter: 1.7e-02
#
# Iter 21200, Loss: 1.363e-01, Rel_L2: 9.885e-01, L_inf: 9.885e-01, t/iter: 1.7e-02
#
# Iter 21300, Loss: 1.363e-01, Rel_L2: 9.882e-01, L_inf: 9.882e-01, t/iter: 1.7e-02
#
# Iter 21400, Loss: 1.362e-01, Rel_L2: 9.879e-01, L_inf: 9.879e-01, t/iter: 1.7e-02
#
# Iter 21500, Loss: 1.362e-01, Rel_L2: 9.876e-01, L_inf: 9.876e-01, t/iter: 1.7e-02
#
# Iter 21600, Loss: 1.362e-01, Rel_L2: 9.874e-01, L_inf: 9.874e-01, t/iter: 1.7e-02
#
# Iter 21700, Loss: 1.361e-01, Rel_L2: 9.872e-01, L_inf: 9.872e-01, t/iter: 1.7e-02
#
# Iter 21800, Loss: 1.361e-01, Rel_L2: 9.870e-01, L_inf: 9.870e-01, t/iter: 1.7e-02
#
# Iter 21900, Loss: 1.361e-01, Rel_L2: 9.869e-01, L_inf: 9.869e-01, t/iter: 1.7e-02
#
# Iter 22000, Loss: 1.360e-01, Rel_L2: 9.868e-01, L_inf: 9.868e-01, t/iter: 1.7e-02
#
# Iter 22100, Loss: 1.360e-01, Rel_L2: 9.867e-01, L_inf: 9.867e-01, t/iter: 1.7e-02
#
# Iter 22200, Loss: 1.359e-01, Rel_L2: 9.866e-01, L_inf: 9.866e-01, t/iter: 1.7e-02
#
# Iter 22300, Loss: 1.359e-01, Rel_L2: 9.866e-01, L_inf: 9.866e-01, t/iter: 1.7e-02
#
# Iter 22400, Loss: 1.359e-01, Rel_L2: 9.865e-01, L_inf: 9.865e-01, t/iter: 1.7e-02
#
# Iter 22500, Loss: 1.358e-01, Rel_L2: 9.865e-01, L_inf: 9.865e-01, t/iter: 1.7e-02
#
# Iter 22600, Loss: 1.358e-01, Rel_L2: 9.865e-01, L_inf: 9.865e-01, t/iter: 1.7e-02
#
# Iter 22700, Loss: 1.357e-01, Rel_L2: 9.864e-01, L_inf: 9.864e-01, t/iter: 1.7e-02
#
# Iter 22800, Loss: 1.357e-01, Rel_L2: 9.864e-01, L_inf: 9.864e-01, t/iter: 1.7e-02
#
# Iter 22900, Loss: 1.356e-01, Rel_L2: 9.864e-01, L_inf: 9.864e-01, t/iter: 1.7e-02
#
# Iter 23000, Loss: 1.356e-01, Rel_L2: 9.864e-01, L_inf: 9.864e-01, t/iter: 1.7e-02
#
# Iter 23100, Loss: 1.355e-01, Rel_L2: 9.865e-01, L_inf: 9.865e-01, t/iter: 1.7e-02
#
# Iter 23200, Loss: 1.355e-01, Rel_L2: 9.865e-01, L_inf: 9.865e-01, t/iter: 1.7e-02
#
# Iter 23300, Loss: 1.354e-01, Rel_L2: 9.865e-01, L_inf: 9.865e-01, t/iter: 1.7e-02
#
# Iter 23400, Loss: 1.353e-01, Rel_L2: 9.866e-01, L_inf: 9.866e-01, t/iter: 1.7e-02
#
# Iter 23500, Loss: 1.352e-01, Rel_L2: 9.866e-01, L_inf: 9.866e-01, t/iter: 1.7e-02
#
# Iter 23600, Loss: 1.351e-01, Rel_L2: 9.867e-01, L_inf: 9.867e-01, t/iter: 1.7e-02
#
# Iter 23700, Loss: 1.350e-01, Rel_L2: 9.868e-01, L_inf: 9.868e-01, t/iter: 1.7e-02
#
# Iter 23800, Loss: 1.348e-01, Rel_L2: 9.869e-01, L_inf: 9.869e-01, t/iter: 1.7e-02
#
# Iter 23900, Loss: 1.347e-01, Rel_L2: 9.871e-01, L_inf: 9.871e-01, t/iter: 1.7e-02
#
# Iter 24000, Loss: 1.345e-01, Rel_L2: 9.873e-01, L_inf: 9.873e-01, t/iter: 1.7e-02
#
# Iter 24100, Loss: 1.343e-01, Rel_L2: 9.875e-01, L_inf: 9.875e-01, t/iter: 1.7e-02
#
# Iter 24200, Loss: 1.340e-01, Rel_L2: 9.879e-01, L_inf: 9.879e-01, t/iter: 1.7e-02
#
# Iter 24300, Loss: 1.337e-01, Rel_L2: 9.883e-01, L_inf: 9.883e-01, t/iter: 1.7e-02
#
# Iter 24400, Loss: 1.334e-01, Rel_L2: 9.889e-01, L_inf: 9.889e-01, t/iter: 1.7e-02
#
# Iter 24500, Loss: 1.330e-01, Rel_L2: 9.898e-01, L_inf: 9.898e-01, t/iter: 1.7e-02
#
# Iter 24600, Loss: 1.326e-01, Rel_L2: 9.902e-01, L_inf: 9.902e-01, t/iter: 1.7e-02
#
# Iter 24700, Loss: 1.322e-01, Rel_L2: 9.918e-01, L_inf: 9.918e-01, t/iter: 1.7e-02
#
# Iter 24800, Loss: 1.322e-01, Rel_L2: 9.942e-01, L_inf: 9.942e-01, t/iter: 1.7e-02
#
# Iter 24900, Loss: 1.317e-01, Rel_L2: 9.936e-01, L_inf: 9.936e-01, t/iter: 1.7e-02
#
# Iter 25000, Loss: 1.315e-01, Rel_L2: 9.946e-01, L_inf: 9.946e-01, t/iter: 1.7e-02
#
# Adjusting learning rate of group 0 to 5.9049e-04.
# Iter 25100, Loss: 1.314e-01, Rel_L2: 9.951e-01, L_inf: 9.951e-01, t/iter: 1.7e-02
#
# Iter 25200, Loss: 1.312e-01, Rel_L2: 9.953e-01, L_inf: 9.953e-01, t/iter: 1.7e-02
#
# Iter 25300, Loss: 1.316e-01, Rel_L2: 9.964e-01, L_inf: 9.964e-01, t/iter: 1.7e-02
#
# Iter 25400, Loss: 1.310e-01, Rel_L2: 9.951e-01, L_inf: 9.951e-01, t/iter: 1.7e-02
#
# Iter 25500, Loss: 1.309e-01, Rel_L2: 9.952e-01, L_inf: 9.952e-01, t/iter: 1.7e-02
#
# Iter 25600, Loss: 1.313e-01, Rel_L2: 9.969e-01, L_inf: 9.969e-01, t/iter: 1.7e-02
#
# Iter 25700, Loss: 1.308e-01, Rel_L2: 9.944e-01, L_inf: 9.944e-01, t/iter: 1.7e-02
#
# Iter 25800, Loss: 1.307e-01, Rel_L2: 9.948e-01, L_inf: 9.948e-01, t/iter: 1.7e-02
#
# Iter 25900, Loss: 1.306e-01, Rel_L2: 9.948e-01, L_inf: 9.948e-01, t/iter: 1.7e-02
#
# Iter 26000, Loss: 1.305e-01, Rel_L2: 9.947e-01, L_inf: 9.947e-01, t/iter: 1.7e-02
#
# Iter 26100, Loss: 1.305e-01, Rel_L2: 9.941e-01, L_inf: 9.941e-01, t/iter: 1.7e-02
#
# Iter 26200, Loss: 1.304e-01, Rel_L2: 9.940e-01, L_inf: 9.940e-01, t/iter: 1.7e-02
#
# Iter 26300, Loss: 1.303e-01, Rel_L2: 9.944e-01, L_inf: 9.944e-01, t/iter: 1.7e-02
#
# Iter 26400, Loss: 1.302e-01, Rel_L2: 9.942e-01, L_inf: 9.942e-01, t/iter: 1.7e-02
#
# Iter 26500, Loss: 1.801e-01, Rel_L2: 9.772e-01, L_inf: 9.772e-01, t/iter: 1.7e-02
#
# Iter 26600, Loss: 1.302e-01, Rel_L2: 9.939e-01, L_inf: 9.939e-01, t/iter: 1.7e-02
#
# Iter 26700, Loss: 1.301e-01, Rel_L2: 9.939e-01, L_inf: 9.939e-01, t/iter: 1.7e-02
#
# Iter 26800, Loss: 1.301e-01, Rel_L2: 9.938e-01, L_inf: 9.938e-01, t/iter: 1.7e-02
#
# Iter 26900, Loss: 1.312e-01, Rel_L2: 9.905e-01, L_inf: 9.905e-01, t/iter: 1.7e-02
#
# Iter 27000, Loss: 1.301e-01, Rel_L2: 9.935e-01, L_inf: 9.935e-01, t/iter: 1.7e-02
#
# Iter 27100, Loss: 1.300e-01, Rel_L2: 9.935e-01, L_inf: 9.935e-01, t/iter: 1.7e-02
#
# Iter 27200, Loss: 1.300e-01, Rel_L2: 9.934e-01, L_inf: 9.934e-01, t/iter: 1.7e-02
#
# Iter 27300, Loss: 1.300e-01, Rel_L2: 9.936e-01, L_inf: 9.936e-01, t/iter: 1.7e-02
#
# Iter 27400, Loss: 1.300e-01, Rel_L2: 9.931e-01, L_inf: 9.931e-01, t/iter: 1.7e-02
#
# Iter 27500, Loss: 1.300e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 27600, Loss: 1.300e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 27700, Loss: 1.300e-01, Rel_L2: 9.932e-01, L_inf: 9.932e-01, t/iter: 1.7e-02
#
# Iter 27800, Loss: 1.357e-01, Rel_L2: 9.868e-01, L_inf: 9.868e-01, t/iter: 1.7e-02
#
# Iter 27900, Loss: 1.300e-01, Rel_L2: 9.934e-01, L_inf: 9.934e-01, t/iter: 1.7e-02
#
# Iter 28000, Loss: 1.300e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 28100, Loss: 1.299e-01, Rel_L2: 9.932e-01, L_inf: 9.932e-01, t/iter: 1.7e-02
#
# Iter 28200, Loss: 1.299e-01, Rel_L2: 9.932e-01, L_inf: 9.932e-01, t/iter: 1.7e-02
#
# Iter 28300, Loss: 1.399e-01, Rel_L2: 1.002e+00, L_inf: 1.002e+00, t/iter: 1.7e-02
#
# Iter 28400, Loss: 1.300e-01, Rel_L2: 9.934e-01, L_inf: 9.934e-01, t/iter: 1.7e-02
#
# Iter 28500, Loss: 1.299e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 28600, Loss: 1.299e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 28700, Loss: 1.299e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 28800, Loss: 1.308e-01, Rel_L2: 9.906e-01, L_inf: 9.906e-01, t/iter: 1.7e-02
#
# Iter 28900, Loss: 1.299e-01, Rel_L2: 9.934e-01, L_inf: 9.934e-01, t/iter: 1.7e-02
#
# Iter 29000, Loss: 1.299e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 29100, Loss: 1.299e-01, Rel_L2: 9.933e-01, L_inf: 9.933e-01, t/iter: 1.7e-02
#
# Iter 29200, Loss: 1.299e-01, Rel_L2: 9.934e-01, L_inf: 9.934e-01, t/iter: 1.7e-02
#
# Iter 29300, Loss: 1.300e-01, Rel_L2: 9.941e-01, L_inf: 9.941e-01, t/iter: 1.7e-02
#
# Iter 29400, Loss: 1.299e-01, Rel_L2: 9.934e-01, L_inf: 9.934e-01, t/iter: 1.7e-02
#
# Iter 29500, Loss: 1.299e-01, Rel_L2: 9.934e-01, L_inf: 9.934e-01, t/iter: 1.7e-02
#
# Iter 29600, Loss: 1.299e-01, Rel_L2: 9.934e-01, L_inf: 9.934e-01, t/iter: 1.7e-02
#
# Iter 29700, Loss: 1.331e-01, Rel_L2: 9.886e-01, L_inf: 9.886e-01, t/iter: 1.7e-02
#
# Iter 29800, Loss: 1.299e-01, Rel_L2: 9.935e-01, L_inf: 9.935e-01, t/iter: 1.7e-02
#
# Iter 29900, Loss: 1.299e-01, Rel_L2: 9.934e-01, L_inf: 9.934e-01, t/iter: 1.7e-02
#
# Iter 30000, Loss: 1.299e-01, Rel_L2: 9.935e-01, L_inf: 9.935e-01, t/iter: 1.7e-02
#
# Adjusting learning rate of group 0 to 5.3144e-04.
# CPU times: user 8min 28s, sys: 3.05 s, total: 8min 31s
# Wall time: 8min 37s

# %%
# Prediction
Exact = Exact0
X, T = np.meshgrid(x0, t0)
X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None]))
u_pred = model.predict(X_star)
U_pred = np.reshape(u_pred, (Exact.shape[1], Exact.shape[0])).T
l2_rel = np.linalg.norm(Exact.flatten() - U_pred.flatten()) / np.linalg.norm(Exact.flatten(), 2)
print('L2:', l2_rel)

plt.figure(1)
plt.title('Abs Error u')
plt.xlabel('t')
plt.ylabel('x') 
plt.imshow(np.abs(Exact-U_pred), aspect='auto', cmap='rainbow')
plt.colorbar()
plt.show()
# Out:
# L2: 0.025224140844888943
